# %% [markdown]
# ## 1. Project Title: Machine Learning for Jewellry Price Optimization
#
# This project aims to successfully predict the prices of jewellry pieces. This will allow the jewelry company reduce their dependence on gemolosists and expensive experts.

# %% [markdown]
# ---
#
# ## 2. Methodology
#
# This project will be carried out using the __CRISP-DM__ methodology. This is one of the more popular data science methodologies and is characterized by six important phases, which are as follows:
#
# 1. _Business Understanding_,
# 2. _Data Understanding_,
# 3. _Data Preparation_,
# 4. _Data Modelling_,
# 5. _Model Evaluation_, and
# 6. _Model Deployment_.
#
# It should be noted that these phases are usually recurrent in nature (i.e., some phases may be repeated). As such, they do not necessarily follow a linear progression.

# %% [markdown]
# ---
#
# ## 3. Tools
#
# The tools of use for this project include:
#
# 1. _Pandas_
# 2. _NumPy_
# 3. _Matplotlib_ & _Seaborn_
#
# #### 3.1. Pandas & NumPy
#
# __Pandas__ is a Python library built upon the __NumPy__ library. The idea behind _Pandas_ is to be able to operate on text data, where _NumPy_ is best suited for numerical operations, irrespective of the fact that it can represent text to some degree.
#
# #### 3.2. Matplotlib & Seaborn
#
# __Matplotlib__ and __Seaborn__ are Python libraries for data visualization. Other alternatives include __Bokeh__ and __Plotly__.

# %% [markdown]
# ---
#
# <div align="center"><h1>Project Implementation via CRISP-DM</h1></div>
#
# ---

# %% [markdown]
# <div><h3>01. Business Understanding</h3></div>

# %% [markdown]
# __Gemineye Emporium__ is a boutique jewelry store based in New York City, U.S., specializing in the sale of high-quality jewelry, in both gemstones and precious metals. They are dedicated to providing customers with exquisite pieces within a market as competitive as the jewelry market.
#
# Specifically, with all the hype about AI and ML, they are interested in leveraging the tools for predicting their jewelery prices. This will be advantageous in optimizing their prices for market, without the need for employing expensive gemologists and certified appraisers.
#
# In order to train the needed machine learning models, the IT team at Gemineye Emporium will need data that records and describes the conditions and state of different jewellery pieces, such as the target gender of the piece, the metal the piece is made of, the gem mounted on the piece, amongst others.
#
# ---

# %% [markdown]
# <div><h3>02. Data Understanding</h3></div>

# %% [markdown]
# With the _**Business Understanding**_ out of the way, the next step is to understand the data to be obtained and used for the task. This will involve the process of __*Exploratory Data Analysis (EDA)*__.
#
# EDA is the process of sifting through data with the goal of extracting insights. These insights allow a better understanding of the available data and what can be done with it. They can also be used for guided preparation of the dataset in the appropriate manner. Just like regular analysis, EDA begins with a set of __questions__ and/or __hypotheses__. The EDA process will then prove or disprove these hypotheses, and hopefully, reveal other points of inquiry along the way.
#
# The required libraries and packages are imported first. The EDA process is carried out here as shown below. The high-level steps to follow are:
#
# 1. Import the required libraries
# 2. Load in the dataset
# 3. Analyze and observe its properties.
#    * Missing data
#    * Inconsistent values
#    * Low categorical cardinality
#    * Feature correlations
# 4. Report on these properties and how they might affect our final solution.

# %% [markdown]
# <div align="center"><h3>2.1. Enter EDA Code Here</h3></div>

# %%
# Import required utilities
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

from sklearn.neighbors import LocalOutlierFactor

# %%
# Seed for reproducibility
SEED = np.random.seed(seed = 2023)

# %%
# Import the dataset
data = pd.read_csv("Jewelry_Datasets/Jewelry_Dataset.csv")
data.columns = [
    "Order_Datetime",
    "Order_ID",
    "Product_ID",
    "SKU_Quantity",
    "Category_ID",
    "Category",
    "Brand_ID",
    "USD_Price",
    "User_ID",
    "Target_Gender",
    "Main_Color",
    "Main_Metal",
    "Main_Gem"
]

# %% [markdown]
# ##### Cardinality

# %%
# Feature cardinality
data.nunique()
# Out:
# Order_Datetime    74504
# Order_ID          74759
# Product_ID         9613
# SKU_Quantity          1
# Category_ID          25
# Category            218
# Brand_ID           2537
# USD_Price          3166
# User_ID           31079
# Target_Gender         2
# Main_Color            5
# Main_Metal            3
# Main_Gem             30
# dtype: int64

# %%
data.head()
# Out:
#             Order_Datetime             Order_ID           Product_ID  \
# 0  2018-12-01 17:38:31 UTC  1924899396621697920  1806829193678291446
# 1  2018-12-02 13:53:42 UTC  1925511016616034733  1842214461889315556
# 2  2018-12-02 17:44:02 UTC  1925626951238681511  1835566849434059453
# 3  2018-12-02 21:30:19 UTC  1925740842841014667  1873936840742928865
# 4  2018-12-02 22:09:34 UTC  1925760595336888995  1835566854827934449
#
#    SKU_Quantity   Category_ID          Category  Brand_ID  USD_Price  \
# 0             1  1.806829e+18               NaN       NaN     212.14
# 1             1  1.806829e+18   jewelry.pendant       1.0      54.66
# 2             1  1.806829e+18   jewelry.pendant       0.0      88.90
# 3             1  1.806829e+18  jewelry.necklace       0.0     417.67
# 4             1  1.806829e+18   jewelry.earring       1.0     102.27
#
#         User_ID Target_Gender Main_Color Main_Metal  Main_Gem
# 0  1.515916e+18           NaN     yellow       gold       NaN
# 1  1.515916e+18             f      white       gold  sapphire
# 2  1.515916e+18             f        red       gold   diamond
# 3  1.515916e+18           NaN        red       gold  amethyst
# 4  1.515916e+18           NaN        red       gold       NaN

# %% [markdown]
# #### Data summary

# %%
# Describe data
data.describe(include="all")
# Out:
#                  Order_Datetime      Order_ID    Product_ID  SKU_Quantity  \
# count                     95910  9.591000e+04  9.591000e+04       95910.0
# unique                    74504           NaN           NaN           NaN
# top     2020-10-17 12:58:28 UTC           NaN           NaN           NaN
# freq                         26           NaN           NaN           NaN
# mean                        NaN  2.485191e+18  1.815970e+18           1.0
# std                         NaN  1.934750e+17  2.136814e+17           0.0
# min                         NaN  1.924899e+18  1.313551e+18           1.0
# 25%                         NaN  2.379732e+18  1.515966e+18           1.0
# 50%                         NaN  2.524282e+18  1.956664e+18           1.0
# 75%                         NaN  2.644347e+18  1.956664e+18           1.0
# max                         NaN  2.719022e+18  2.541962e+18           1.0
#
#          Category_ID         Category      Brand_ID     USD_Price  \
# count   9.055800e+04            85977  9.112500e+04  90558.000000
# unique           NaN              218           NaN           NaN
# top              NaN  jewelry.earring           NaN           NaN
# freq             NaN            29051           NaN           NaN
# mean    1.805947e+18              NaN  8.891036e+16    362.213017
# std     2.083954e+16              NaN  3.559651e+17    444.157665
# min     1.313678e+18              NaN  0.000000e+00      0.990000
# 25%     1.806829e+18              NaN  0.000000e+00    145.620000
# 50%     1.806829e+18              NaN  1.000000e+00    258.770000
# 75%     1.806829e+18              NaN  1.000000e+00    431.370000
# max     1.806829e+18              NaN  1.550613e+18  34448.600000
#
#              User_ID Target_Gender Main_Color Main_Metal Main_Gem
# count   9.055800e+04         47743      88250      90448    61852
# unique           NaN             2          5          3       30
# top              NaN             f        red       gold  diamond
# freq             NaN         47379      69510      89081    29609
# mean    1.512644e+18           NaN        NaN        NaN      NaN
# std     2.374776e+16           NaN        NaN        NaN      NaN
# min     1.313554e+18           NaN        NaN        NaN      NaN
# 25%     1.515916e+18           NaN        NaN        NaN      NaN
# 50%     1.515916e+18           NaN        NaN        NaN      NaN
# 75%     1.515916e+18           NaN        NaN        NaN      NaN
# max     1.554297e+18           NaN        NaN        NaN      NaN

# %% [markdown]
# ##### Missing Values

# %%
# Check for missing values
100 * data.isnull().sum() / len(data)
# Out:
# Order_Datetime     0.000000
# Order_ID           0.000000
# Product_ID         0.000000
# SKU_Quantity       0.000000
# Category_ID        5.580231
# Category          10.356584
# Brand_ID           4.989052
# USD_Price          5.580231
# User_ID            5.580231
# Target_Gender     50.221041
# Main_Color         7.986654
# Main_Metal         5.694922
# Main_Gem          35.510374
# dtype: float64

# %%
print(data.shape)
# Out:
# (95910, 13)

# %% [markdown]
# ##### Low cardinality

# %%
# Number of unique values per feature
data.nunique()
# Out:
# Order_Datetime    74504
# Order_ID          74759
# Product_ID         9613
# SKU_Quantity          1
# Category_ID          25
# Category            218
# Brand_ID           2537
# USD_Price          3166
# User_ID           31079
# Target_Gender         2
# Main_Color            5
# Main_Metal            3
# Main_Gem             30
# dtype: int64

# %% [markdown]
# Apart from the target variable, which is the jewelry price, all other variables may be considered categorical in nature. Also, the _SKU_Quantity_ feature has just one unique value, giving it a variance of 0. As such, it conferrs no new informative property on the dataset.

# %% [markdown]
# ##### Duplicate records
#
# We eliminate duplicated rows.

# %%
# Get the duplicated records
num_duplicated = len(data.loc[data.duplicated()])

# %%
print(f"Number of duplicated records: {num_duplicated}.")
# Out:
# Number of duplicated records: 2589.

# %%
# Filter away the duplicated records
data = data.loc[~data.duplicated()]

# %% [markdown]
# ##### Target Distribution

# %%
# Bar chart
plt.figure(figsize = (15, 5))
sns.kdeplot(data = data, x = "USD_Price")
plt.xlabel("Jewellery Price")
plt.ylabel("Label Frequency")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Promise Sunday\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# The jewelry prices, which are the target labels, are right-skewed i.e., most outliers exist on the high end. This may imply that most jewelry pieces are sold to  more regular, mainstream buyers, while high-value sales are rarely conducted.

# %% [markdown]
# ##### Target Gender Analysis
#
# According to social norms, females are more likely to be interested in jewelry than their male counterparts [[PAPER](https://www.jcreview.com/admin/Uploads/Files/61ded785882d06.51262907.pdf)], and this skew can be very extreme. It can be interesting to see how this might reflect in this dataset.

# %%
# Jewelry target gender distribution
data["Target_Gender"].value_counts()
# Out:
# Target_Gender
# f    46687
# m      359
# Name: count, dtype: int64

# %%
# Jewelry target gender distribution
data["Target_Gender"].value_counts(normalize = True) * 100
# Out:
# Target_Gender
# f    99.236917
# m     0.763083
# Name: proportion, dtype: float64

# %%
# Visualize jewelry distribution by gender
plt.figure(figsize = (12, 8))

sns.countplot(data=data, x = "Target_Gender", width = 0.3)
plt.title("Distribution of jewelry based on target gender", fontsize=25, pad=20)

plt.xlabel("Target Gender", fontsize=20, labelpad=20)
plt.ylabel("Jewelry sample size", fontsize=20, labelpad=20)

plt.xticks([0, 1], ['FEMALE', 'MALE'])

plt.show(); plt.close("all")

# %% [markdown]
# Based on the short univariate analysis above, we can conclude that a majority of jewelry pieces are specifically targeted toward women. This would probably be a result of market analysis.
#
# We can thus assume that the __male__ value in the __Target_Gender__ column is a rare one. This leaves us with one of two options:
#
# 1. Retain the column or
# 2. Eliminate the column, as it does not give us much diversity within gender.
#
# Since this state of affairs is an actual representation of the real-world distribution and how the genders interact with jewelry, the final decision we will make here will be to retain the column.

# %% [markdown]
# ##### Jewelry Category Analysis
#
# It would make some sense to observe the different jewelry categories on sale.

# %%
# Jewelry category distribution
data["Category"].value_counts()
# Out:
# Category
# jewelry.earring     29047
# jewelry.ring        26025
# jewelry.pendant     13083
# jewelry.bracelet     6129
# 0.00                 4311
#                     ...
# 626.58                  1
# 13.42                   1
# 2.88                    1
# 101.23                  1
# 253.77                  1
# Name: count, Length: 218, dtype: int64

# %%
# Top 10 categories by sample size
data["Category"].value_counts()[:10]
# Out:
# Category
# jewelry.earring       29047
# jewelry.ring          26025
# jewelry.pendant       13083
# jewelry.bracelet       6129
# 0.00                   4311
# jewelry.necklace       2335
# jewelry.brooch         1286
# jewelry.souvenir        170
# electronics.clocks      165
# 40.82                    54
# Name: count, dtype: int64

# %%
data["Category"].unique()
# Out:
# array([nan, 'jewelry.pendant', 'jewelry.necklace', 'jewelry.earring',
#        'jewelry.ring', 'jewelry.brooch', 'jewelry.bracelet',
#        'electronics.clocks', 'jewelry.souvenir', '230.12', '202.36',
#        '1098.03', '321.78', '1128.62', '81.27', '34.25', '582.16',
#        '227.37', '234.22', '150.55', '131.82', '2123.15', '109.45',
#        '49.22', '472.47', '205.38', '2746.44', '51.08', '231.12', '76.97',
#        '3054.73', '184.90', '380.10', '357.49', '15.47', '135.33',
#        '719.75', '93.01', '177.95', 'jewelry.stud', '102.10', '595.75',
#        '469.56', '427.07', '53.62', '77.53', '1469.18', '355.27',
#        '184.89', '154.66', '300.58', '83.73', '271.19', '3294.21',
#        '278.04', '3626.26', '126.03', '283.52', '114.38', '89.04', '8.22',
#        '124.88', '89.73', '171.23', '136.93', '19.04', '158.77', '187.10',
#        '151.92', '1845.89', '87.23', '248.58', '596.48', '208.88',
#        '193.11', '169.84', '1447.68', '45.07', '136.85', '282.05',
#        '61.51', '210.21', '137.12', '147.81', '419.45', '825.27',
#        '300.16', '541.78', '308.74', '766.85', '410.82', '101.23', '2.88',
#        '1356.16', '13.42', '35.21', '134.79', '626.58', '13.70', '108.53',
#        '119.01', '7.40', '4.79', '153.97', '482.47', '427.36', '289.18',
#        '25.48', '1858.49', '21.70', '11.77', '198.89', '17.51', '574.66',
#        '1319.93', '393.05', '358.22', '2282.19', '114.93', '371.23',
#        '63.56', '88.77', '133.70', '117.81', '166.03', '130.41', '195.75',
#        '104.79', '228.59', '1686.93', '65.89', '242.19', '252.47',
#        '210.41', '363.42', '149.04', '157.95', '176.30', '160.96',
#        '316.30', '258.77', '268.36', '838.90', '250.96', '832.01',
#        '312.33', '318.71', '323.60', '205.34', '608.22', '343.84',
#        '598.22', '508.08', '245.67', '338.36', '75.21', '573.81',
#        '691.51', '476.68', '247.68', '286.71', '863.67', '236.58',
#        '644.66', '40.82', '1376.99', '1.23', '621.23', '3454.79', '65.62',
#        '59.73', '571.30', '70.96', '271.26', '958.84', '527.26', '271.16',
#        '284.66', '261.64', '493.01', '35.48', '446.16', '526.41',
#        '2517.08', '331.51', '312.88', '148.63', '451.21', '369.82',
#        '537.40', '231.51', '316.34', '451.10', '283.49', '787.67',
#        '131.92', '495.48', '5.48', '186.03', '484.49', '331.23', '133.85',
#        '323.70', '2635.07', '297.22', '0.00', '259.58', '108.33',
#        '4876.49', '308.08', '190.27', '916.44', '132.53', '1829.37',
#        '2208.90', '75.76', '278.01', '662.30', '253.77'], dtype=object)

# %% [markdown]
# From the short analysis done above, it can be seen that a portion of the data has been corrupted. Rather than containing the accurate jewelry categories, some records contain stringified numerical values instead. This may be due to a number of possible issues such as:
#
# 1. Corrupted data recording process
# 2. Lack of accurate data dictionary (these numerical values may encode some information about other jewelry categories)
#
# Also, it was observed that some records did not describe jewelry, they described electronic clocks instead. These records will have to be filtered out. We can also see that the only jewelry item that seems to be targeted towards the men are _rings_.

# %% [markdown]
# We can extract the actual jewelry categories of interest.

# %%
# Exctract real jewelry categories
categories = data["Category"].unique().tolist()
categories = [c for c in categories if isinstance(c, str) and c.__contains__("jewelry")]

# %%
categories
# Out:
# ['jewelry.pendant',
#  'jewelry.necklace',
#  'jewelry.earring',
#  'jewelry.ring',
#  'jewelry.brooch',
#  'jewelry.bracelet',
#  'jewelry.souvenir',
#  'jewelry.stud']

# %%
# Extract records with the real categories
real_categories = data.loc[data["Category"].isin(categories), :]

# %%
# Check for missing values
100 * real_categories.isnull().sum() / len(data)
# Out:
# Order_Datetime     0.000000
# Order_ID           0.000000
# Product_ID         0.000000
# SKU_Quantity       0.000000
# Category_ID        0.000000
# Category           0.000000
# Brand_ID           3.609048
# USD_Price          0.000000
# User_ID            0.000000
# Target_Gender     36.833082
# Main_Color         2.009194
# Main_Metal         0.092155
# Main_Gem          19.378275
# dtype: float64

# %%
# Visualize the jewelry category via pie chart

jewelry_categories, counts = real_categories["Category"].value_counts().index.tolist(), real_categories["Category"].value_counts().values

plt.figure(figsize = (15, 8))
plt.pie(x=counts, labels=jewelry_categories)

plt.title("Pie Plot of Jewelry Category", fontsize=25, pad=20)

plt.show(); plt.close("all")

# %%
# Visualize the countplot for jewelry category
plt.figure(figsize = (15, 8))
sns.countplot(data=real_categories, x = "Category")

plt.title("Countplot of Jewelry Category", fontsize=25, pad=20)

plt.xlabel("Jewelry Category", fontsize=15, labelpad=10)
plt.ylabel("Frequency", fontsize=15, labelpad=10)

plt.show(); plt.close("all")

# %%
# Visualize the jewelry sample distribution based on jewelry category
plt.figure(figsize = (15, 8))
sns.histplot(data=real_categories, x = "Category")

plt.title("Histogram Plot of Jewelry Category", fontsize=25, pad=20)

plt.xlabel("Jewelry Category", fontsize=15, labelpad=10)
plt.ylabel("Frequency", fontsize=15, labelpad=10)

plt.show(); plt.close("all")
# Out:
# C:\Users\Promise Sunday\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# We can also look at a breakdown of the different jewelry categories by target gender.

# %%
# Jewelry category by gender
plt.figure(figsize = (15, 8))
sns.countplot(data=real_categories, x = "Category", hue = "Target_Gender")

plt.title("Jewelry Category by Target Gender", fontsize=25, pad=20)

plt.xlabel("Jewelry Category", fontsize=15, labelpad=10)
plt.ylabel("Frequency", fontsize=15, labelpad=10)

plt.show(); plt.close("all")

# %%
# Jewelry target gender distribution
real_categories["Target_Gender"].value_counts(normalize=True) * 100
# Out:
# Target_Gender
# f    99.444114
# m     0.555886
# Name: proportion, dtype: float64

# %% [markdown]
# ##### Feature correlation
#
# It would make some sense to observe the features for colinearity. As most of the features in the dataset are categorical, the __Spearman Rank correlation coefficient__ will be utilized.

# %%
encoded, category_codes = pd.factorize(real_categories["Category"])
real_categories.loc[:, "Category"] = encoded

# %%
encoded, category_codes = pd.factorize(real_categories["Target_Gender"])
real_categories.loc[:, "Target_Gender"] = encoded

# %%
encoded, category_codes = pd.factorize(real_categories["Main_Color"])
real_categories.loc[:, "Main_Color"] = encoded

# %%
encoded, category_codes = pd.factorize(real_categories["Main_Gem"])
real_categories.loc[:, "Main_Gem"] = encoded

# %%
encoded, category_codes = pd.factorize(real_categories["Main_Metal"])
real_categories.loc[:, "Main_Metal"] = encoded

# %%
# Obtain Spearman Rank correlation coeficients for all features
correlations = real_categories.drop(["Order_Datetime", "User_ID", "Order_ID"], axis=1).corr("spearman")

# %%
correlations
# Out:
#                Product_ID  SKU_Quantity  Category_ID  Category  Brand_ID  \
# Product_ID       1.000000           NaN    -0.067612  0.045974 -0.167567
# SKU_Quantity          NaN           NaN          NaN       NaN       NaN
# Category_ID     -0.067612           NaN     1.000000 -0.883445  0.102341
# Category         0.045974           NaN    -0.883445  1.000000 -0.103630
# Brand_ID        -0.167567           NaN     0.102341 -0.103630  1.000000
# USD_Price       -0.005826           NaN    -0.304429  0.274393 -0.024357
# Target_Gender   -0.174900           NaN     0.092612 -0.112309  0.621894
# Main_Color       0.007825           NaN    -0.005701 -0.053113  0.093239
# Main_Metal      -0.070714           NaN     0.159114  0.106521  0.002909
# Main_Gem        -0.085904           NaN     0.029780 -0.064541  0.058302
#
#                USD_Price  Target_Gender  Main_Color  Main_Metal  Main_Gem
# Product_ID     -0.005826      -0.174900    0.007825   -0.070714 -0.085904
# SKU_Quantity         NaN            NaN         NaN         NaN       NaN
# Category_ID    -0.304429       0.092612   -0.005701    0.159114  0.029780
# Category        0.274393      -0.112309   -0.053113    0.106521 -0.064541
# Brand_ID       -0.024357       0.621894    0.093239    0.002909  0.058302
# USD_Price       1.000000       0.046484    0.009921   -0.175966 -0.014676
# Target_Gender   0.046484       1.000000    0.045873   -0.049423  0.148043
# Main_Color      0.009921       0.045873    1.000000   -0.244682  0.127346
# Main_Metal     -0.175966      -0.049423   -0.244682    1.000000 -0.058735
# Main_Gem       -0.014676       0.148043    0.127346   -0.058735  1.000000

# %%
# Correlation heatmap
plt.figure(figsize = (10, 10))
sns.heatmap(correlations, annot=correlations, center=.3)
plt.show()

# %%
correlations
# Out:
#                Product_ID  SKU_Quantity  Category_ID  Category  Brand_ID  \
# Product_ID       1.000000           NaN    -0.067612  0.045974 -0.167567
# SKU_Quantity          NaN           NaN          NaN       NaN       NaN
# Category_ID     -0.067612           NaN     1.000000 -0.883445  0.102341
# Category         0.045974           NaN    -0.883445  1.000000 -0.103630
# Brand_ID        -0.167567           NaN     0.102341 -0.103630  1.000000
# USD_Price       -0.005826           NaN    -0.304429  0.274393 -0.024357
# Target_Gender   -0.174900           NaN     0.092612 -0.112309  0.621894
# Main_Color       0.007825           NaN    -0.005701 -0.053113  0.093239
# Main_Metal      -0.070714           NaN     0.159114  0.106521  0.002909
# Main_Gem        -0.085904           NaN     0.029780 -0.064541  0.058302
#
#                USD_Price  Target_Gender  Main_Color  Main_Metal  Main_Gem
# Product_ID     -0.005826      -0.174900    0.007825   -0.070714 -0.085904
# SKU_Quantity         NaN            NaN         NaN         NaN       NaN
# Category_ID    -0.304429       0.092612   -0.005701    0.159114  0.029780
# Category        0.274393      -0.112309   -0.053113    0.106521 -0.064541
# Brand_ID       -0.024357       0.621894    0.093239    0.002909  0.058302
# USD_Price       1.000000       0.046484    0.009921   -0.175966 -0.014676
# Target_Gender   0.046484       1.000000    0.045873   -0.049423  0.148043
# Main_Color      0.009921       0.045873    1.000000   -0.244682  0.127346
# Main_Metal     -0.175966      -0.049423   -0.244682    1.000000 -0.058735
# Main_Gem       -0.014676       0.148043    0.127346   -0.058735  1.000000

# %%
# Set correlation limits
lower_corr_limits = .2
upper_corr_limits = 1.

# %%
correlated_columns = {
    column: correlations[(correlations[column] > lower_corr_limits) & (upper_corr_limits > correlations[column])].index.tolist()
    for column in correlations.columns
}

# %%
correlated_columns
# Out:
# {'Product_ID': [],
#  'SKU_Quantity': [],
#  'Category_ID': [],
#  'Category': ['USD_Price'],
#  'Brand_ID': ['Target_Gender'],
#  'USD_Price': ['Category'],
#  'Target_Gender': ['Brand_ID'],
#  'Main_Color': [],
#  'Main_Metal': [],
#  'Main_Gem': []}

# %%
num_correlated_columns = {k: len(v) for k, v in correlated_columns.items()}

# %%
num_correlated_columns
# Out:
# {'Product_ID': 0,
#  'SKU_Quantity': 0,
#  'Category_ID': 0,
#  'Category': 1,
#  'Brand_ID': 1,
#  'USD_Price': 1,
#  'Target_Gender': 1,
#  'Main_Color': 0,
#  'Main_Metal': 0,
#  'Main_Gem': 0}

# %% [markdown]
# From the correlation analysis above, it is obvious that most of the features exhibit low correlations with one another and with the target variable itself. This may be taken as a mix of good and bad news.
#
# The good news is that there is little colinearity among the features. This is good for feature independence, which might imply that each variable encodes information that might be relatively orthogonal to the information encoded within other variables. The bad news is, that any model trained in these features might have a difficult time learning anything from the data, as the target variable has little correlation with the independent variables.

# %% [markdown]
# #### 2.2. Data Implications
#
# Implied by our findings above, we can say the following:
#
# 1. ___Missing values and outliers___: There are a lot of missing values in the dataset. This may be fixed either by value imputation of missingness encoding. As regards outliers, there are quite a lot also. These can be filtered out.
#
# 2. ___Data corruption___: Some variables, (e.g., _jewelry_category_) contain corrupt values.
#
# 3. ___Rare values___: Some features have some values that occur rarely. A prime instance of this is the _Target_Gender_ column, where the _male_ gender is rarely represented. Sometimes, these are data issues. Other times, like in this case, this can be a true reflection of the distribution from which the data is generated.
#
# 4. ___Low cardinality or feature invariance___: The _SKU_Quantity_ feature only has one unique value (e.g., 1). This feature provideds no new information.
#
# 5. ___Target skew___: The target variable is highly right-skewed. This can present an issue during training.
#
# 6. ___Correlation___: For the most part, the features exhibit low multicollinearity, hence ensuring feature independence. However, the target variable exhibits a low correlation with the independent variables.
#
#
# ---

# %% [markdown]
# <div><h3>03. Data Preparation</h3></div>

# %% [markdown]
# Based on the *__Data Implications__* discovered prior, the following steps will be experimented upon for the data preparation stage.
#
# 1. __Missing Values__: The missing values will be treated via an algorithmic method, ___SimpleImputer___.
#
# 2. __Feature Encoding__: The categorical features will be encoded.
#
# 3. __Redundant Features__: Certain features will be eliminated for a number of reasons. These are:
#    1. _SKU_Quantity_: Feature invariance
#
#    2. _Order_ID_: Simple identifier; has no real-world influence on jewelry price.
#
#    3. _Product_ID_: Same with _Order_ID_.
#
#    4. _Order_Datetime_: Avoid data leakage; would not be available in real-world.
#
# 4. __Target Skew__: The target variabloe is strongly right-skewed. This can be an issue when learning a mapping from the data space to the label space. Thiis issue will be fixed using the ___TransformedTargetRegressor___ utility.
#
# ___NOTE___:
# Most of the data preparation steps will be carried out via the use of ___Pipeline___ class from _Sci-kit learn_. The Pipeline object allows us to chain transformers and estimators sequentially for use as one composite object.

# %% [markdown]
# <div align="center"><h3>3.1. Enter Data Preparation Code Here</h3></div>

# %%
from sklearn.model_selection import train_test_split

from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder, PowerTransformer
from sklearn.compose import ColumnTransformer, TransformedTargetRegressor

from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import AdaBoostRegressor, ExtraTreesRegressor

from catboost import CatBoostRegressor

from sklearn.base import BaseEstimator, TransformerMixin

# %%
# Columns to drop
to_drop = [
    "SKU_Quantity",
    "Order_ID",
    "Product_ID",
    "Order_Datetime",
    "User_ID",
    "Category_ID"

]

# %%
data.drop(labels = to_drop, axis=1, inplace=True)

# %%
data.head()
# Out:
#            Category  Brand_ID  USD_Price Target_Gender Main_Color Main_Metal  \
# 0               NaN       NaN     212.14           NaN     yellow       gold
# 1   jewelry.pendant       1.0      54.66             f      white       gold
# 2   jewelry.pendant       0.0      88.90             f        red       gold
# 3  jewelry.necklace       0.0     417.67           NaN        red       gold
# 4   jewelry.earring       1.0     102.27           NaN        red       gold
#
#    Main_Gem
# 0       NaN
# 1  sapphire
# 2   diamond
# 3  amethyst
# 4       NaN

# %%
data.nunique()
# Out:
# Category          218
# Brand_ID         2537
# USD_Price        3166
# Target_Gender       2
# Main_Color          5
# Main_Metal          3
# Main_Gem           30
# dtype: int64

# %%
data.shape
# Out:
# (93321, 7)

# %%
# Extract records with the real categories

del real_categories
data = data.loc[data["Category"].isin(categories), :]

# %%
data.nunique()
# Out:
# Category            8
# Brand_ID            6
# USD_Price        2849
# Target_Gender       2
# Main_Color          4
# Main_Metal          3
# Main_Gem           30
# dtype: int64

# %%
data.head()
# Out:
#            Category  Brand_ID  USD_Price Target_Gender Main_Color Main_Metal  \
# 1   jewelry.pendant       1.0      54.66             f      white       gold
# 2   jewelry.pendant       0.0      88.90             f        red       gold
# 3  jewelry.necklace       0.0     417.67           NaN        red       gold
# 4   jewelry.earring       1.0     102.27           NaN        red       gold
# 5   jewelry.earring       0.0     150.55           NaN        red       gold
#
#    Main_Gem
# 1  sapphire
# 2   diamond
# 3  amethyst
# 4       NaN
# 5   diamond

# %%
data.isnull().sum()
# Out:
# Category             0
# Brand_ID          3368
# USD_Price            0
# Target_Gender    34373
# Main_Color        1875
# Main_Metal          86
# Main_Gem         18084
# dtype: int64

# %%
# Extract features and labels
X, y = data.drop(labels = ["USD_Price"], axis=1), data['USD_Price']

# %%
# Column indexes
columns = X.columns.tolist()
column_indexes = [i for i in range(len(X.columns))]

# %%
# Split data into test and train sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

# %% [markdown]
# ---

# %% [markdown]
# <div><h3>04. Data Modelling</h3></div>

# %% [markdown]
# With the data well-prepared now, the modeling can begin. A number of learning algorithms will be tested. They are:
#
# 1. ___Linear Regression___,
# 2. ___Extremely Random Forest (ExtraTrees)___,
# 3. ___Adaptive Boosting (AdaBoost)___, and
# 4. ___Catboost___.

# %% [markdown]
# #### 4.1. Modelling

# %%
# Categorical columns
categorical_columns = ["Category", "Target_Gender", "Main_Color", "Main_Gem", "Main_Metal"]
categorical_columns_index = [columns.index(c) for c in categorical_columns]

# %%
categorical_columns_index
# Out:
# [0, 2, 3, 5, 4]

# %% [markdown]
# Here, we will instantiate a data transformation pipeline. We will attempt to do the following:
#
# 1. Input missing values (___SimpleImputer___)
# 2. Encode categorical variables. This can be done via ___OrdinalEncoder___ or ___OneHotEncoder___. The logic behind the final choice will be discussed below.
#
# These transformations discussed are going to be applied optionally. Some models like __Catboost__ do not need any value imputation technique from the user, as they have their internal mechanism for that. Models like linear regression will require it, however. The same idea applies to the process of encoding the categorical variables.
#
# For models like __Catboost__, all we need to do is ensure that these categorical variables are represented as numbers. They can then be handled internally [[CatBoost Docs](https://catboost.ai/en/docs/features/categorical-features)]. For other models like __linear regression__, not only do these variables have to be represented as numbers, but they have to be one-hot encoded to prevent the model from treating them as regular continuous variables.

# %%
def pipeline(model, fill_missing = True, set_categorical = True, use_label_encoder = False):
    first_encoder = ColumnTransformer(
        transformers = [
            ("imputer", SimpleImputer(strategy = "most_frequent"), column_indexes),
        ],
        remainder = "passthrough",
        sparse_threshold = 0.
    )

    second_encoder = ColumnTransformer(
        transformers = [
            ("one_hot", OneHotEncoder(), categorical_columns_index),
        ],
        remainder = "passthrough",
        sparse_threshold = 0.
    )

    third_encoder = ColumnTransformer(
        transformers = [
            ("label", OrdinalEncoder(), categorical_columns_index),
        ],
        remainder = "passthrough",
        sparse_threshold = 0.
    )

    steps = []

    if fill_missing:
        steps.append(("first_encoder", first_encoder))
    if use_label_encoder:
        steps.append(("third_encoder", third_encoder))
    if set_categorical:
        steps.append(("second_encoder", second_encoder))

    steps.append(("model", model))

    model_pipeline = Pipeline(
        steps = steps
    )

    return model_pipeline

# %%
# Instantiate mopdel pipelines
cat_pipe = pipeline(
    CatBoostRegressor(loss_function="RMSE", bagging_temperature=.4, iterations=10000, learning_rate=0.1, one_hot_max_size=2),
    fill_missing=False, set_categorical = False, use_label_encoder = True
)

linear_pipe = pipeline(
    LinearRegression(),
    fill_missing=True, set_categorical =True, use_label_encoder = False
)

extra_pipe = pipeline(
    ExtraTreesRegressor(criterion="friedman_mse", n_estimators = 1000, bootstrap=True),
    fill_missing=True, set_categorical =True, use_label_encoder = False
)

ada_pipe = pipeline(
    AdaBoostRegressor(loss="exponential", n_estimators = 1000, learning_rate=.01),
    fill_missing=True, set_categorical =True, use_label_encoder = False
)

# %%
# Transform target for all model pipelines
cat_pipe = TransformedTargetRegressor(regressor = cat_pipe, transformer = PowerTransformer(method = "box-cox"))
linear_pipe = TransformedTargetRegressor(regressor = linear_pipe, transformer = PowerTransformer(method = "box-cox"))
extra_pipe = TransformedTargetRegressor(regressor = extra_pipe, transformer = PowerTransformer(method = "box-cox"))
ada_pipe = TransformedTargetRegressor(regressor = ada_pipe, transformer = PowerTransformer(method = "box-cox"))

# %%
cat_pipe.fit(X_train, y_train)
# Out:
# 0:	learn: 0.9566459	total: 102ms	remaining: 17m 1s
# 1:	learn: 0.9208793	total: 123ms	remaining: 10m 16s
# 2:	learn: 0.8930995	total: 143ms	remaining: 7m 56s
# 3:	learn: 0.8659360	total: 158ms	remaining: 6m 35s
# 4:	learn: 0.8459906	total: 177ms	remaining: 5m 54s
# 5:	learn: 0.8294126	total: 198ms	remaining: 5m 29s
# 6:	learn: 0.8124553	total: 218ms	remaining: 5m 11s
# 7:	learn: 0.7973382	total: 239ms	remaining: 4m 57s
# 8:	learn: 0.7865281	total: 261ms	remaining: 4m 50s
# 9:	learn: 0.7767989	total: 281ms	remaining: 4m 40s
# 10:	learn: 0.7684968	total: 301ms	remaining: 4m 33s
# 11:	learn: 0.7597648	total: 320ms	remaining: 4m 26s
# 12:	learn: 0.7534756	total: 333ms	remaining: 4m 16s
# 13:	learn: 0.7478924	total: 355ms	remaining: 4m 13s
# 14:	learn: 0.7430314	total: 375ms	remaining: 4m 9s
# 15:	learn: 0.7363634	total: 396ms	remaining: 4m 6s
# 16:	learn: 0.7316242	total: 416ms	remaining: 4m 4s
# 17:	learn: 0.7263678	total: 436ms	remaining: 4m 1s
# 18:	learn: 0.7232753	total: 456ms	remaining: 3m 59s
# 19:	learn: 0.7189202	total: 476ms	remaining: 3m 57s
# 20:	learn: 0.7160428	total: 496ms	remaining: 3m 55s
# 21:	learn: 0.7129202	total: 515ms	remaining: 3m 53s
# 22:	learn: 0.7099978	total: 538ms	remaining: 3m 53s
# 23:	learn: 0.7070724	total: 552ms	remaining: 3m 49s
# 24:	learn: 0.7056117	total: 572ms	remaining: 3m 48s
# 25:	learn: 0.7036014	total: 593ms	remaining: 3m 47s
# 26:	learn: 0.7004083	total: 613ms	remaining: 3m 46s
# 27:	learn: 0.6982378	total: 634ms	remaining: 3m 45s
# 28:	learn: 0.6969807	total: 653ms	remaining: 3m 44s
# 29:	learn: 0.6957243	total: 671ms	remaining: 3m 43s
# 30:	learn: 0.6937697	total: 691ms	remaining: 3m 42s
# 31:	learn: 0.6927173	total: 712ms	remaining: 3m 41s
# 32:	learn: 0.6910534	total: 731ms	remaining: 3m 40s
# 33:	learn: 0.6903632	total: 751ms	remaining: 3m 39s
# 34:	learn: 0.6879888	total: 767ms	remaining: 3m 38s
# 35:	learn: 0.6869492	total: 787ms	remaining: 3m 37s
# 36:	learn: 0.6855980	total: 807ms	remaining: 3m 37s
# 37:	learn: 0.6846053	total: 827ms	remaining: 3m 36s
# 38:	learn: 0.6834252	total: 847ms	remaining: 3m 36s
# 39:	learn: 0.6828487	total: 866ms	remaining: 3m 35s
# 40:	learn: 0.6818159	total: 886ms	remaining: 3m 35s
# 41:	learn: 0.6808219	total: 906ms	remaining: 3m 34s
# 42:	learn: 0.6791974	total: 929ms	remaining: 3m 35s
# 43:	learn: 0.6788707	total: 952ms	remaining: 3m 35s
# 44:	learn: 0.6782812	total: 978ms	remaining: 3m 36s
# 45:	learn: 0.6775405	total: 1.01s	remaining: 3m 38s
# 46:	learn: 0.6768331	total: 1.03s	remaining: 3m 38s
# 47:	learn: 0.6759831	total: 1.06s	remaining: 3m 39s
# 48:	learn: 0.6744859	total: 1.08s	remaining: 3m 39s
# 49:	learn: 0.6737962	total: 1.11s	remaining: 3m 41s
# 50:	learn: 0.6732504	total: 1.13s	remaining: 3m 41s
# 51:	learn: 0.6729360	total: 1.15s	remaining: 3m 40s
# 52:	learn: 0.6726076	total: 1.17s	remaining: 3m 40s
# 53:	learn: 0.6721990	total: 1.19s	remaining: 3m 40s
# 54:	learn: 0.6717612	total: 1.21s	remaining: 3m 38s
# 55:	learn: 0.6712520	total: 1.23s	remaining: 3m 37s
# 56:	learn: 0.6705284	total: 1.25s	remaining: 3m 37s
# 57:	learn: 0.6695151	total: 1.27s	remaining: 3m 37s
# 58:	learn: 0.6689640	total: 1.28s	remaining: 3m 36s
# 59:	learn: 0.6685205	total: 1.3s	remaining: 3m 36s
# 60:	learn: 0.6678426	total: 1.32s	remaining: 3m 35s
# 61:	learn: 0.6670681	total: 1.34s	remaining: 3m 35s
# 62:	learn: 0.6668039	total: 1.36s	remaining: 3m 34s
# 63:	learn: 0.6665086	total: 1.38s	remaining: 3m 34s
# 64:	learn: 0.6659304	total: 1.4s	remaining: 3m 34s
# 65:	learn: 0.6655930	total: 1.42s	remaining: 3m 33s
# 66:	learn: 0.6649284	total: 1.43s	remaining: 3m 32s
# 67:	learn: 0.6646481	total: 1.46s	remaining: 3m 32s
# 68:	learn: 0.6642695	total: 1.48s	remaining: 3m 32s
# 69:	learn: 0.6638566	total: 1.5s	remaining: 3m 32s
# 70:	learn: 0.6636722	total: 1.51s	remaining: 3m 31s
# 71:	learn: 0.6634565	total: 1.53s	remaining: 3m 31s
# 72:	learn: 0.6630322	total: 1.55s	remaining: 3m 30s
# 73:	learn: 0.6629091	total: 1.57s	remaining: 3m 30s
# 74:	learn: 0.6628087	total: 1.59s	remaining: 3m 30s
# 75:	learn: 0.6626548	total: 1.61s	remaining: 3m 29s
# 76:	learn: 0.6624479	total: 1.62s	remaining: 3m 29s
# 77:	learn: 0.6618808	total: 1.64s	remaining: 3m 28s
# 78:	learn: 0.6612717	total: 1.66s	remaining: 3m 28s
# 79:	learn: 0.6604416	total: 1.68s	remaining: 3m 28s
# 80:	learn: 0.6601398	total: 1.7s	remaining: 3m 27s
# 81:	learn: 0.6600349	total: 1.72s	remaining: 3m 27s
# 82:	learn: 0.6597150	total: 1.73s	remaining: 3m 27s
# 83:	learn: 0.6596525	total: 1.75s	remaining: 3m 26s
# 84:	learn: 0.6595081	total: 1.77s	remaining: 3m 26s
# 85:	learn: 0.6588310	total: 1.79s	remaining: 3m 26s
# 86:	learn: 0.6584004	total: 1.81s	remaining: 3m 26s
# 87:	learn: 0.6581164	total: 1.83s	remaining: 3m 25s
# 88:	learn: 0.6580059	total: 1.84s	remaining: 3m 24s
# 89:	learn: 0.6575669	total: 1.86s	remaining: 3m 24s
# 90:	learn: 0.6573445	total: 1.88s	remaining: 3m 24s
# 91:	learn: 0.6572042	total: 1.9s	remaining: 3m 24s
# 92:	learn: 0.6570696	total: 1.91s	remaining: 3m 23s
# 93:	learn: 0.6568971	total: 1.93s	remaining: 3m 23s
# 94:	learn: 0.6567739	total: 1.95s	remaining: 3m 23s
# 95:	learn: 0.6566916	total: 1.97s	remaining: 3m 23s
# 96:	learn: 0.6564235	total: 1.99s	remaining: 3m 22s
# 97:	learn: 0.6563509	total: 2s	remaining: 3m 22s
# 98:	learn: 0.6561355	total: 2.02s	remaining: 3m 22s
# 99:	learn: 0.6559918	total: 2.04s	remaining: 3m 22s
# 100:	learn: 0.6557406	total: 2.06s	remaining: 3m 21s
# 101:	learn: 0.6555369	total: 2.07s	remaining: 3m 21s
# 102:	learn: 0.6552593	total: 2.09s	remaining: 3m 21s
# 103:	learn: 0.6546576	total: 2.11s	remaining: 3m 21s
# 104:	learn: 0.6546079	total: 2.13s	remaining: 3m 20s
# 105:	learn: 0.6543366	total: 2.15s	remaining: 3m 20s
# 106:	learn: 0.6538669	total: 2.17s	remaining: 3m 20s
# 107:	learn: 0.6536116	total: 2.19s	remaining: 3m 20s
# 108:	learn: 0.6534603	total: 2.21s	remaining: 3m 20s
# 109:	learn: 0.6533416	total: 2.23s	remaining: 3m 20s
# 110:	learn: 0.6531563	total: 2.25s	remaining: 3m 20s
# 111:	learn: 0.6529397	total: 2.26s	remaining: 3m 19s
# 112:	learn: 0.6527547	total: 2.27s	remaining: 3m 18s
# 113:	learn: 0.6525322	total: 2.29s	remaining: 3m 18s
# 114:	learn: 0.6523293	total: 2.31s	remaining: 3m 18s
# 115:	learn: 0.6518447	total: 2.34s	remaining: 3m 19s
# 116:	learn: 0.6516706	total: 2.35s	remaining: 3m 18s
# 117:	learn: 0.6515153	total: 2.37s	remaining: 3m 18s
# 118:	learn: 0.6514416	total: 2.39s	remaining: 3m 18s
# 119:	learn: 0.6512710	total: 2.41s	remaining: 3m 18s
# 120:	learn: 0.6510888	total: 2.43s	remaining: 3m 18s
# 121:	learn: 0.6509588	total: 2.45s	remaining: 3m 18s
# 122:	learn: 0.6508032	total: 2.47s	remaining: 3m 18s
# 123:	learn: 0.6506401	total: 2.48s	remaining: 3m 17s
# 124:	learn: 0.6504262	total: 2.5s	remaining: 3m 17s
# 125:	learn: 0.6503139	total: 2.52s	remaining: 3m 17s
# 126:	learn: 0.6501139	total: 2.54s	remaining: 3m 17s
# 127:	learn: 0.6499791	total: 2.56s	remaining: 3m 17s
# 128:	learn: 0.6498547	total: 2.58s	remaining: 3m 17s
# 129:	learn: 0.6497119	total: 2.59s	remaining: 3m 17s
# 130:	learn: 0.6495123	total: 2.61s	remaining: 3m 16s
# 131:	learn: 0.6494775	total: 2.63s	remaining: 3m 16s
# 132:	learn: 0.6493114	total: 2.65s	remaining: 3m 16s
# 133:	learn: 0.6492194	total: 2.67s	remaining: 3m 16s
# 134:	learn: 0.6490206	total: 2.69s	remaining: 3m 16s
# 135:	learn: 0.6488801	total: 2.71s	remaining: 3m 16s
# 136:	learn: 0.6485219	total: 2.73s	remaining: 3m 16s
# 137:	learn: 0.6484218	total: 2.74s	remaining: 3m 16s
# 138:	learn: 0.6482284	total: 2.76s	remaining: 3m 16s
# 139:	learn: 0.6481041	total: 2.78s	remaining: 3m 15s
# 140:	learn: 0.6478917	total: 2.8s	remaining: 3m 15s
# 141:	learn: 0.6474138	total: 2.82s	remaining: 3m 15s
# 142:	learn: 0.6471347	total: 2.84s	remaining: 3m 15s
# 143:	learn: 0.6469879	total: 2.86s	remaining: 3m 15s
# 144:	learn: 0.6467923	total: 2.88s	remaining: 3m 15s
# 145:	learn: 0.6466337	total: 2.9s	remaining: 3m 15s
# 146:	learn: 0.6465182	total: 2.91s	remaining: 3m 15s
# 147:	learn: 0.6464430	total: 2.93s	remaining: 3m 15s
# 148:	learn: 0.6461596	total: 2.95s	remaining: 3m 15s
# 149:	learn: 0.6459881	total: 2.97s	remaining: 3m 14s
# 150:	learn: 0.6458812	total: 2.99s	remaining: 3m 14s
# 151:	learn: 0.6458019	total: 3.01s	remaining: 3m 15s
# 152:	learn: 0.6455866	total: 3.03s	remaining: 3m 14s
# 153:	learn: 0.6455204	total: 3.05s	remaining: 3m 14s
# 154:	learn: 0.6454136	total: 3.07s	remaining: 3m 14s
# 155:	learn: 0.6453051	total: 3.09s	remaining: 3m 15s
# 156:	learn: 0.6451882	total: 3.15s	remaining: 3m 17s
# 157:	learn: 0.6450347	total: 3.19s	remaining: 3m 18s
# 158:	learn: 0.6449482	total: 3.21s	remaining: 3m 18s
# 159:	learn: 0.6447864	total: 3.25s	remaining: 3m 20s
# 160:	learn: 0.6447456	total: 3.27s	remaining: 3m 19s
# 161:	learn: 0.6445444	total: 3.29s	remaining: 3m 19s
# 162:	learn: 0.6444534	total: 3.3s	remaining: 3m 19s
# 163:	learn: 0.6442712	total: 3.32s	remaining: 3m 19s
# 164:	learn: 0.6441600	total: 3.34s	remaining: 3m 19s
# 165:	learn: 0.6440970	total: 3.36s	remaining: 3m 18s
# 166:	learn: 0.6439624	total: 3.38s	remaining: 3m 18s
# 167:	learn: 0.6438849	total: 3.39s	remaining: 3m 18s
# 168:	learn: 0.6437438	total: 3.41s	remaining: 3m 18s
# 169:	learn: 0.6434876	total: 3.43s	remaining: 3m 18s
# 170:	learn: 0.6434159	total: 3.45s	remaining: 3m 18s
# 171:	learn: 0.6432497	total: 3.47s	remaining: 3m 18s
# 172:	learn: 0.6431414	total: 3.49s	remaining: 3m 18s
# 173:	learn: 0.6430734	total: 3.51s	remaining: 3m 18s
# 174:	learn: 0.6429723	total: 3.52s	remaining: 3m 17s
# 175:	learn: 0.6428878	total: 3.54s	remaining: 3m 17s
# 176:	learn: 0.6427229	total: 3.56s	remaining: 3m 17s
# 177:	learn: 0.6423888	total: 3.58s	remaining: 3m 17s
# 178:	learn: 0.6422172	total: 3.6s	remaining: 3m 17s
# 179:	learn: 0.6420102	total: 3.62s	remaining: 3m 17s
# 180:	learn: 0.6419573	total: 3.64s	remaining: 3m 17s
# 181:	learn: 0.6419220	total: 3.66s	remaining: 3m 17s
# 182:	learn: 0.6417847	total: 3.68s	remaining: 3m 17s
# 183:	learn: 0.6417222	total: 3.7s	remaining: 3m 17s
# 184:	learn: 0.6416303	total: 3.71s	remaining: 3m 17s
# 185:	learn: 0.6415067	total: 3.73s	remaining: 3m 16s
# 186:	learn: 0.6413016	total: 3.75s	remaining: 3m 16s
# 187:	learn: 0.6411771	total: 3.77s	remaining: 3m 16s
# 188:	learn: 0.6411195	total: 3.79s	remaining: 3m 16s
# 189:	learn: 0.6410132	total: 3.81s	remaining: 3m 16s
# 190:	learn: 0.6409756	total: 3.82s	remaining: 3m 16s
# 191:	learn: 0.6407497	total: 3.84s	remaining: 3m 16s
# 192:	learn: 0.6405704	total: 3.86s	remaining: 3m 16s
# 193:	learn: 0.6404020	total: 3.88s	remaining: 3m 16s
# 194:	learn: 0.6403794	total: 3.9s	remaining: 3m 16s
# 195:	learn: 0.6402210	total: 3.92s	remaining: 3m 15s
# 196:	learn: 0.6401043	total: 3.93s	remaining: 3m 15s
# 197:	learn: 0.6399772	total: 3.95s	remaining: 3m 15s
# 198:	learn: 0.6398583	total: 3.97s	remaining: 3m 15s
# 199:	learn: 0.6398087	total: 3.99s	remaining: 3m 15s
# 200:	learn: 0.6396785	total: 4s	remaining: 3m 15s
# 201:	learn: 0.6395742	total: 4.02s	remaining: 3m 15s
# 202:	learn: 0.6395192	total: 4.04s	remaining: 3m 15s
# 203:	learn: 0.6394108	total: 4.06s	remaining: 3m 14s
# 204:	learn: 0.6392874	total: 4.08s	remaining: 3m 14s
# 205:	learn: 0.6391509	total: 4.1s	remaining: 3m 14s
# 206:	learn: 0.6391283	total: 4.12s	remaining: 3m 14s
# 207:	learn: 0.6390463	total: 4.13s	remaining: 3m 14s
# 208:	learn: 0.6389835	total: 4.15s	remaining: 3m 14s
# 209:	learn: 0.6389406	total: 4.17s	remaining: 3m 14s
# 210:	learn: 0.6388701	total: 4.19s	remaining: 3m 14s
# 211:	learn: 0.6388365	total: 4.21s	remaining: 3m 14s
# 212:	learn: 0.6387685	total: 4.22s	remaining: 3m 14s
# 213:	learn: 0.6386024	total: 4.25s	remaining: 3m 14s
# 214:	learn: 0.6385187	total: 4.26s	remaining: 3m 14s
# 215:	learn: 0.6384627	total: 4.28s	remaining: 3m 13s
# 216:	learn: 0.6383877	total: 4.3s	remaining: 3m 13s
# 217:	learn: 0.6382211	total: 4.32s	remaining: 3m 13s
# 218:	learn: 0.6380000	total: 4.34s	remaining: 3m 13s
# 219:	learn: 0.6379291	total: 4.36s	remaining: 3m 13s
# 220:	learn: 0.6378888	total: 4.37s	remaining: 3m 13s
# 221:	learn: 0.6377841	total: 4.39s	remaining: 3m 13s
# 222:	learn: 0.6377501	total: 4.41s	remaining: 3m 13s
# 223:	learn: 0.6376325	total: 4.43s	remaining: 3m 13s
# 224:	learn: 0.6374955	total: 4.45s	remaining: 3m 13s
# 225:	learn: 0.6374058	total: 4.47s	remaining: 3m 13s
# 226:	learn: 0.6373487	total: 4.49s	remaining: 3m 13s
# 227:	learn: 0.6373038	total: 4.51s	remaining: 3m 13s
# 228:	learn: 0.6371478	total: 4.53s	remaining: 3m 13s
# 229:	learn: 0.6370952	total: 4.54s	remaining: 3m 13s
# 230:	learn: 0.6370317	total: 4.56s	remaining: 3m 12s
# 231:	learn: 0.6369986	total: 4.57s	remaining: 3m 12s
# 232:	learn: 0.6369487	total: 4.59s	remaining: 3m 12s
# 233:	learn: 0.6367434	total: 4.61s	remaining: 3m 12s
# 234:	learn: 0.6367250	total: 4.63s	remaining: 3m 12s
# 235:	learn: 0.6366998	total: 4.65s	remaining: 3m 12s
# 236:	learn: 0.6366720	total: 4.67s	remaining: 3m 12s
# 237:	learn: 0.6365787	total: 4.68s	remaining: 3m 12s
# 238:	learn: 0.6363519	total: 4.7s	remaining: 3m 12s
# 239:	learn: 0.6363346	total: 4.72s	remaining: 3m 12s
# 240:	learn: 0.6362434	total: 4.74s	remaining: 3m 12s
# 241:	learn: 0.6360799	total: 4.76s	remaining: 3m 12s
# 242:	learn: 0.6360567	total: 4.78s	remaining: 3m 11s
# 243:	learn: 0.6360433	total: 4.79s	remaining: 3m 11s
# 244:	learn: 0.6360287	total: 4.8s	remaining: 3m 11s
# 245:	learn: 0.6359692	total: 4.82s	remaining: 3m 11s
# 246:	learn: 0.6358898	total: 4.84s	remaining: 3m 11s
# 247:	learn: 0.6358243	total: 4.86s	remaining: 3m 11s
# 248:	learn: 0.6357761	total: 4.88s	remaining: 3m 11s
# 249:	learn: 0.6357438	total: 4.9s	remaining: 3m 11s
# 250:	learn: 0.6357209	total: 4.92s	remaining: 3m 10s
# 251:	learn: 0.6356262	total: 4.94s	remaining: 3m 11s
# 252:	learn: 0.6355165	total: 4.96s	remaining: 3m 10s
# 253:	learn: 0.6354798	total: 4.97s	remaining: 3m 10s
# 254:	learn: 0.6353994	total: 4.99s	remaining: 3m 10s
# 255:	learn: 0.6351595	total: 5s	remaining: 3m 10s
# 256:	learn: 0.6350476	total: 5.03s	remaining: 3m 10s
# 257:	learn: 0.6348613	total: 5.04s	remaining: 3m 10s
# 258:	learn: 0.6347936	total: 5.06s	remaining: 3m 10s
# 259:	learn: 0.6347288	total: 5.08s	remaining: 3m 10s
# 260:	learn: 0.6346930	total: 5.1s	remaining: 3m 10s
# 261:	learn: 0.6346031	total: 5.12s	remaining: 3m 10s
# 262:	learn: 0.6345309	total: 5.14s	remaining: 3m 10s
# 263:	learn: 0.6344982	total: 5.16s	remaining: 3m 10s
# 264:	learn: 0.6344460	total: 5.18s	remaining: 3m 10s
# 265:	learn: 0.6342293	total: 5.2s	remaining: 3m 10s
# 266:	learn: 0.6341284	total: 5.22s	remaining: 3m 10s
# 267:	learn: 0.6340321	total: 5.24s	remaining: 3m 10s
# 268:	learn: 0.6339737	total: 5.27s	remaining: 3m 10s
# 269:	learn: 0.6338098	total: 5.29s	remaining: 3m 10s
# 270:	learn: 0.6337526	total: 5.32s	remaining: 3m 11s
# 271:	learn: 0.6336845	total: 5.35s	remaining: 3m 11s
# 272:	learn: 0.6336561	total: 5.38s	remaining: 3m 11s
# 273:	learn: 0.6334903	total: 5.4s	remaining: 3m 11s
# 274:	learn: 0.6334658	total: 5.42s	remaining: 3m 11s
# 275:	learn: 0.6334169	total: 5.43s	remaining: 3m 11s
# 276:	learn: 0.6333626	total: 5.45s	remaining: 3m 11s
# 277:	learn: 0.6333230	total: 5.47s	remaining: 3m 11s
# 278:	learn: 0.6332613	total: 5.49s	remaining: 3m 11s
# 279:	learn: 0.6332494	total: 5.51s	remaining: 3m 11s
# 280:	learn: 0.6331594	total: 5.54s	remaining: 3m 11s
# 281:	learn: 0.6331388	total: 5.56s	remaining: 3m 11s
# 282:	learn: 0.6330599	total: 5.59s	remaining: 3m 11s
# 283:	learn: 0.6330459	total: 5.61s	remaining: 3m 12s
# 284:	learn: 0.6329344	total: 5.64s	remaining: 3m 12s
# 285:	learn: 0.6328981	total: 5.65s	remaining: 3m 12s
# 286:	learn: 0.6328383	total: 5.67s	remaining: 3m 11s
# 287:	learn: 0.6327956	total: 5.69s	remaining: 3m 11s
# 288:	learn: 0.6327507	total: 5.71s	remaining: 3m 11s
# 289:	learn: 0.6326348	total: 5.73s	remaining: 3m 11s
# 290:	learn: 0.6325829	total: 5.76s	remaining: 3m 12s
# 291:	learn: 0.6325094	total: 5.78s	remaining: 3m 12s
# 292:	learn: 0.6324952	total: 5.81s	remaining: 3m 12s
# 293:	learn: 0.6324746	total: 5.83s	remaining: 3m 12s
# 294:	learn: 0.6324529	total: 5.86s	remaining: 3m 12s
# 295:	learn: 0.6324362	total: 5.88s	remaining: 3m 12s
# 296:	learn: 0.6323716	total: 5.9s	remaining: 3m 12s
# 297:	learn: 0.6323228	total: 5.92s	remaining: 3m 12s
# 298:	learn: 0.6322650	total: 5.93s	remaining: 3m 12s
# 299:	learn: 0.6322538	total: 5.95s	remaining: 3m 12s
# 300:	learn: 0.6322187	total: 5.97s	remaining: 3m 12s
# 301:	learn: 0.6322070	total: 5.99s	remaining: 3m 12s
# 302:	learn: 0.6321302	total: 6s	remaining: 3m 12s
# 303:	learn: 0.6321097	total: 6.02s	remaining: 3m 12s
# 304:	learn: 0.6320756	total: 6.04s	remaining: 3m 12s
# 305:	learn: 0.6320421	total: 6.07s	remaining: 3m 12s
# 306:	learn: 0.6319869	total: 6.09s	remaining: 3m 12s
# 307:	learn: 0.6319368	total: 6.12s	remaining: 3m 12s
# 308:	learn: 0.6318764	total: 6.14s	remaining: 3m 12s
# 309:	learn: 0.6317399	total: 6.17s	remaining: 3m 12s
# 310:	learn: 0.6316957	total: 6.2s	remaining: 3m 13s
# 311:	learn: 0.6316809	total: 6.22s	remaining: 3m 13s
# 312:	learn: 0.6316592	total: 6.24s	remaining: 3m 13s
# 313:	learn: 0.6315230	total: 6.26s	remaining: 3m 12s
# 314:	learn: 0.6314536	total: 6.28s	remaining: 3m 13s
# 315:	learn: 0.6314279	total: 6.29s	remaining: 3m 12s
# 316:	learn: 0.6313798	total: 6.3s	remaining: 3m 12s
# 317:	learn: 0.6313704	total: 6.32s	remaining: 3m 12s
# 318:	learn: 0.6312603	total: 6.34s	remaining: 3m 12s
# 319:	learn: 0.6312417	total: 6.36s	remaining: 3m 12s
# 320:	learn: 0.6310298	total: 6.38s	remaining: 3m 12s
# 321:	learn: 0.6309686	total: 6.41s	remaining: 3m 12s
# 322:	learn: 0.6309383	total: 6.44s	remaining: 3m 12s
# 323:	learn: 0.6308349	total: 6.46s	remaining: 3m 13s
# 324:	learn: 0.6307952	total: 6.49s	remaining: 3m 13s
# 325:	learn: 0.6307172	total: 6.51s	remaining: 3m 13s
# 326:	learn: 0.6306701	total: 6.54s	remaining: 3m 13s
# 327:	learn: 0.6305595	total: 6.56s	remaining: 3m 13s
# 328:	learn: 0.6305264	total: 6.58s	remaining: 3m 13s
# 329:	learn: 0.6303908	total: 6.6s	remaining: 3m 13s
# 330:	learn: 0.6303908	total: 6.61s	remaining: 3m 13s
# 331:	learn: 0.6303576	total: 6.63s	remaining: 3m 12s
# 332:	learn: 0.6303497	total: 6.64s	remaining: 3m 12s
# 333:	learn: 0.6302546	total: 6.66s	remaining: 3m 12s
# 334:	learn: 0.6302372	total: 6.68s	remaining: 3m 12s
# 335:	learn: 0.6301629	total: 6.7s	remaining: 3m 12s
# 336:	learn: 0.6301158	total: 6.72s	remaining: 3m 12s
# 337:	learn: 0.6300979	total: 6.74s	remaining: 3m 12s
# 338:	learn: 0.6300623	total: 6.76s	remaining: 3m 12s
# 339:	learn: 0.6300399	total: 6.79s	remaining: 3m 12s
# 340:	learn: 0.6299966	total: 6.82s	remaining: 3m 13s
# 341:	learn: 0.6299792	total: 6.84s	remaining: 3m 13s
# 342:	learn: 0.6299370	total: 6.87s	remaining: 3m 13s
# 343:	learn: 0.6298450	total: 6.89s	remaining: 3m 13s
# 344:	learn: 0.6298142	total: 6.91s	remaining: 3m 13s
# 345:	learn: 0.6298039	total: 6.92s	remaining: 3m 13s
# 346:	learn: 0.6297940	total: 6.93s	remaining: 3m 12s
# 347:	learn: 0.6297809	total: 6.96s	remaining: 3m 12s
# 348:	learn: 0.6297605	total: 6.98s	remaining: 3m 13s
# 349:	learn: 0.6297444	total: 7.01s	remaining: 3m 13s
# 350:	learn: 0.6297274	total: 7.04s	remaining: 3m 13s
# 351:	learn: 0.6297029	total: 7.06s	remaining: 3m 13s
# 352:	learn: 0.6296195	total: 7.09s	remaining: 3m 13s
# 353:	learn: 0.6295755	total: 7.12s	remaining: 3m 13s
# 354:	learn: 0.6295579	total: 7.13s	remaining: 3m 13s
# 355:	learn: 0.6295579	total: 7.14s	remaining: 3m 13s
# 356:	learn: 0.6295445	total: 7.15s	remaining: 3m 13s
# 357:	learn: 0.6295296	total: 7.17s	remaining: 3m 13s
# 358:	learn: 0.6295185	total: 7.19s	remaining: 3m 13s
# 359:	learn: 0.6294789	total: 7.22s	remaining: 3m 13s
# 360:	learn: 0.6294367	total: 7.26s	remaining: 3m 13s
# 361:	learn: 0.6293780	total: 7.29s	remaining: 3m 14s
# 362:	learn: 0.6293663	total: 7.31s	remaining: 3m 14s
# 363:	learn: 0.6292250	total: 7.34s	remaining: 3m 14s
# 364:	learn: 0.6291826	total: 7.36s	remaining: 3m 14s
# 365:	learn: 0.6291723	total: 7.41s	remaining: 3m 15s
# 366:	learn: 0.6290715	total: 7.44s	remaining: 3m 15s
# 367:	learn: 0.6290213	total: 7.47s	remaining: 3m 15s
# 368:	learn: 0.6290095	total: 7.52s	remaining: 3m 16s
# 369:	learn: 0.6289758	total: 7.55s	remaining: 3m 16s
# 370:	learn: 0.6289027	total: 7.57s	remaining: 3m 16s
# 371:	learn: 0.6288897	total: 7.59s	remaining: 3m 16s
# 372:	learn: 0.6288081	total: 7.62s	remaining: 3m 16s
# 373:	learn: 0.6287806	total: 7.65s	remaining: 3m 16s
# 374:	learn: 0.6287166	total: 7.67s	remaining: 3m 16s
# 375:	learn: 0.6286801	total: 7.69s	remaining: 3m 16s
# 376:	learn: 0.6286618	total: 7.71s	remaining: 3m 16s
# 377:	learn: 0.6286278	total: 7.73s	remaining: 3m 16s
# 378:	learn: 0.6285588	total: 7.75s	remaining: 3m 16s
# 379:	learn: 0.6285016	total: 7.76s	remaining: 3m 16s
# 380:	learn: 0.6284137	total: 7.78s	remaining: 3m 16s
# 381:	learn: 0.6283607	total: 7.79s	remaining: 3m 16s
# 382:	learn: 0.6282796	total: 7.81s	remaining: 3m 16s
# 383:	learn: 0.6282319	total: 7.84s	remaining: 3m 16s
# 384:	learn: 0.6282213	total: 7.87s	remaining: 3m 16s
# 385:	learn: 0.6281378	total: 7.89s	remaining: 3m 16s
# 386:	learn: 0.6280473	total: 7.92s	remaining: 3m 16s
# 387:	learn: 0.6280059	total: 7.95s	remaining: 3m 16s
# 388:	learn: 0.6279734	total: 7.97s	remaining: 3m 17s
# 389:	learn: 0.6279663	total: 7.99s	remaining: 3m 16s
# 390:	learn: 0.6279577	total: 8s	remaining: 3m 16s
# 391:	learn: 0.6278855	total: 8.02s	remaining: 3m 16s
# 392:	learn: 0.6278502	total: 8.03s	remaining: 3m 16s
# 393:	learn: 0.6278389	total: 8.05s	remaining: 3m 16s
# 394:	learn: 0.6278231	total: 8.07s	remaining: 3m 16s
# 395:	learn: 0.6277746	total: 8.09s	remaining: 3m 16s
# 396:	learn: 0.6277590	total: 8.11s	remaining: 3m 16s
# 397:	learn: 0.6277259	total: 8.13s	remaining: 3m 16s
# 398:	learn: 0.6276918	total: 8.15s	remaining: 3m 16s
# 399:	learn: 0.6276867	total: 8.17s	remaining: 3m 16s
# 400:	learn: 0.6276831	total: 8.2s	remaining: 3m 16s
# 401:	learn: 0.6275977	total: 8.22s	remaining: 3m 16s
# 402:	learn: 0.6275820	total: 8.24s	remaining: 3m 16s
# 403:	learn: 0.6275646	total: 8.27s	remaining: 3m 16s
# 404:	learn: 0.6275325	total: 8.29s	remaining: 3m 16s
# 405:	learn: 0.6274874	total: 8.31s	remaining: 3m 16s
# 406:	learn: 0.6274716	total: 8.33s	remaining: 3m 16s
# 407:	learn: 0.6274383	total: 8.35s	remaining: 3m 16s
# 408:	learn: 0.6274186	total: 8.37s	remaining: 3m 16s
# 409:	learn: 0.6273908	total: 8.39s	remaining: 3m 16s
# 410:	learn: 0.6273621	total: 8.4s	remaining: 3m 16s
# 411:	learn: 0.6272745	total: 8.42s	remaining: 3m 15s
# 412:	learn: 0.6272109	total: 8.44s	remaining: 3m 15s
# 413:	learn: 0.6271585	total: 8.46s	remaining: 3m 15s
# 414:	learn: 0.6271061	total: 8.47s	remaining: 3m 15s
# 415:	learn: 0.6270870	total: 8.49s	remaining: 3m 15s
# 416:	learn: 0.6270250	total: 8.51s	remaining: 3m 15s
# 417:	learn: 0.6270105	total: 8.53s	remaining: 3m 15s
# 418:	learn: 0.6269761	total: 8.55s	remaining: 3m 15s
# 419:	learn: 0.6269630	total: 8.58s	remaining: 3m 15s
# 420:	learn: 0.6268955	total: 8.61s	remaining: 3m 15s
# 421:	learn: 0.6268701	total: 8.63s	remaining: 3m 15s
# 422:	learn: 0.6267968	total: 8.65s	remaining: 3m 15s
# 423:	learn: 0.6267609	total: 8.68s	remaining: 3m 16s
# 424:	learn: 0.6267500	total: 8.71s	remaining: 3m 16s
# 425:	learn: 0.6266366	total: 8.72s	remaining: 3m 16s
# 426:	learn: 0.6265742	total: 8.74s	remaining: 3m 16s
# 427:	learn: 0.6264821	total: 8.76s	remaining: 3m 15s
# 428:	learn: 0.6264442	total: 8.78s	remaining: 3m 15s
# 429:	learn: 0.6264060	total: 8.8s	remaining: 3m 15s
# 430:	learn: 0.6263875	total: 8.82s	remaining: 3m 15s
# 431:	learn: 0.6263757	total: 8.83s	remaining: 3m 15s
# 432:	learn: 0.6263708	total: 8.85s	remaining: 3m 15s
# 433:	learn: 0.6263519	total: 8.86s	remaining: 3m 15s
# 434:	learn: 0.6263308	total: 8.88s	remaining: 3m 15s
# 435:	learn: 0.6263105	total: 8.9s	remaining: 3m 15s
# 436:	learn: 0.6262814	total: 8.92s	remaining: 3m 15s
# 437:	learn: 0.6262582	total: 8.94s	remaining: 3m 15s
# 438:	learn: 0.6262395	total: 8.96s	remaining: 3m 15s
# 439:	learn: 0.6262076	total: 8.98s	remaining: 3m 15s
# 440:	learn: 0.6261858	total: 9.01s	remaining: 3m 15s
# 441:	learn: 0.6261689	total: 9.04s	remaining: 3m 15s
# 442:	learn: 0.6261627	total: 9.06s	remaining: 3m 15s
# 443:	learn: 0.6261451	total: 9.07s	remaining: 3m 15s
# 444:	learn: 0.6261264	total: 9.1s	remaining: 3m 15s
# 445:	learn: 0.6261164	total: 9.13s	remaining: 3m 15s
# 446:	learn: 0.6260472	total: 9.14s	remaining: 3m 15s
# 447:	learn: 0.6260097	total: 9.16s	remaining: 3m 15s
# 448:	learn: 0.6259670	total: 9.19s	remaining: 3m 15s
# 449:	learn: 0.6259522	total: 9.2s	remaining: 3m 15s
# 450:	learn: 0.6258816	total: 9.22s	remaining: 3m 15s
# 451:	learn: 0.6258398	total: 9.24s	remaining: 3m 15s
# 452:	learn: 0.6257963	total: 9.26s	remaining: 3m 15s
# 453:	learn: 0.6257820	total: 9.27s	remaining: 3m 14s
# 454:	learn: 0.6257582	total: 9.28s	remaining: 3m 14s
# 455:	learn: 0.6257296	total: 9.3s	remaining: 3m 14s
# 456:	learn: 0.6256846	total: 9.32s	remaining: 3m 14s
# 457:	learn: 0.6256283	total: 9.34s	remaining: 3m 14s
# 458:	learn: 0.6255870	total: 9.36s	remaining: 3m 14s
# 459:	learn: 0.6255751	total: 9.38s	remaining: 3m 14s
# 460:	learn: 0.6255591	total: 9.39s	remaining: 3m 14s
# 461:	learn: 0.6255073	total: 9.41s	remaining: 3m 14s
# 462:	learn: 0.6254966	total: 9.43s	remaining: 3m 14s
# 463:	learn: 0.6254501	total: 9.45s	remaining: 3m 14s
# 464:	learn: 0.6254432	total: 9.46s	remaining: 3m 14s
# 465:	learn: 0.6253968	total: 9.48s	remaining: 3m 13s
# 466:	learn: 0.6253726	total: 9.49s	remaining: 3m 13s
# 467:	learn: 0.6253567	total: 9.52s	remaining: 3m 13s
# 468:	learn: 0.6253435	total: 9.54s	remaining: 3m 13s
# 469:	learn: 0.6253253	total: 9.55s	remaining: 3m 13s
# 470:	learn: 0.6252466	total: 9.57s	remaining: 3m 13s
# 471:	learn: 0.6252312	total: 9.59s	remaining: 3m 13s
# 472:	learn: 0.6252211	total: 9.61s	remaining: 3m 13s
# 473:	learn: 0.6251949	total: 9.63s	remaining: 3m 13s
# 474:	learn: 0.6251741	total: 9.65s	remaining: 3m 13s
# 475:	learn: 0.6251686	total: 9.67s	remaining: 3m 13s
# 476:	learn: 0.6251383	total: 9.68s	remaining: 3m 13s
# 477:	learn: 0.6251225	total: 9.69s	remaining: 3m 13s
# 478:	learn: 0.6251018	total: 9.71s	remaining: 3m 12s
# 479:	learn: 0.6250766	total: 9.72s	remaining: 3m 12s
# 480:	learn: 0.6250074	total: 9.74s	remaining: 3m 12s
# 481:	learn: 0.6249850	total: 9.76s	remaining: 3m 12s
# 482:	learn: 0.6249607	total: 9.78s	remaining: 3m 12s
# 483:	learn: 0.6249343	total: 9.8s	remaining: 3m 12s
# 484:	learn: 0.6248978	total: 9.82s	remaining: 3m 12s
# 485:	learn: 0.6248913	total: 9.84s	remaining: 3m 12s
# 486:	learn: 0.6248792	total: 9.86s	remaining: 3m 12s
# 487:	learn: 0.6248636	total: 9.88s	remaining: 3m 12s
# 488:	learn: 0.6248568	total: 9.89s	remaining: 3m 12s
# 489:	learn: 0.6248413	total: 9.9s	remaining: 3m 12s
# 490:	learn: 0.6248294	total: 9.92s	remaining: 3m 12s
# 491:	learn: 0.6248128	total: 9.94s	remaining: 3m 12s
# 492:	learn: 0.6247804	total: 9.96s	remaining: 3m 12s
# 493:	learn: 0.6247727	total: 9.97s	remaining: 3m 11s
# 494:	learn: 0.6247597	total: 9.99s	remaining: 3m 11s
# 495:	learn: 0.6247463	total: 10s	remaining: 3m 11s
# 496:	learn: 0.6247440	total: 10s	remaining: 3m 11s
# 497:	learn: 0.6247357	total: 10s	remaining: 3m 11s
# 498:	learn: 0.6246836	total: 10.1s	remaining: 3m 11s
# 499:	learn: 0.6246774	total: 10.1s	remaining: 3m 11s
# 500:	learn: 0.6246522	total: 10.1s	remaining: 3m 11s
# 501:	learn: 0.6246310	total: 10.1s	remaining: 3m 11s
# 502:	learn: 0.6246144	total: 10.1s	remaining: 3m 11s
# 503:	learn: 0.6245910	total: 10.2s	remaining: 3m 11s
# 504:	learn: 0.6245877	total: 10.2s	remaining: 3m 11s
# 505:	learn: 0.6245808	total: 10.2s	remaining: 3m 11s
# 506:	learn: 0.6245587	total: 10.2s	remaining: 3m 11s
# 507:	learn: 0.6245513	total: 10.2s	remaining: 3m 11s
# 508:	learn: 0.6244686	total: 10.2s	remaining: 3m 11s
# 509:	learn: 0.6244439	total: 10.3s	remaining: 3m 11s
# 510:	learn: 0.6244146	total: 10.3s	remaining: 3m 11s
# 511:	learn: 0.6244029	total: 10.3s	remaining: 3m 10s
# 512:	learn: 0.6243928	total: 10.3s	remaining: 3m 10s
# 513:	learn: 0.6243826	total: 10.3s	remaining: 3m 10s
# 514:	learn: 0.6243808	total: 10.3s	remaining: 3m 10s
# 515:	learn: 0.6243591	total: 10.4s	remaining: 3m 10s
# 516:	learn: 0.6243400	total: 10.4s	remaining: 3m 10s
# 517:	learn: 0.6243089	total: 10.4s	remaining: 3m 10s
# 518:	learn: 0.6242783	total: 10.4s	remaining: 3m 10s
# 519:	learn: 0.6242524	total: 10.4s	remaining: 3m 10s
# 520:	learn: 0.6242345	total: 10.5s	remaining: 3m 10s
# 521:	learn: 0.6242310	total: 10.5s	remaining: 3m 10s
# 522:	learn: 0.6242231	total: 10.5s	remaining: 3m 10s
# 523:	learn: 0.6241906	total: 10.5s	remaining: 3m 10s
# 524:	learn: 0.6241737	total: 10.5s	remaining: 3m 9s
# 525:	learn: 0.6241567	total: 10.5s	remaining: 3m 9s
# 526:	learn: 0.6241414	total: 10.6s	remaining: 3m 9s
# 527:	learn: 0.6241263	total: 10.6s	remaining: 3m 9s
# 528:	learn: 0.6241263	total: 10.6s	remaining: 3m 9s
# 529:	learn: 0.6240933	total: 10.6s	remaining: 3m 9s
# 530:	learn: 0.6240807	total: 10.6s	remaining: 3m 9s
# 531:	learn: 0.6240759	total: 10.6s	remaining: 3m 9s
# 532:	learn: 0.6240722	total: 10.7s	remaining: 3m 9s
# 533:	learn: 0.6240665	total: 10.7s	remaining: 3m 9s
# 534:	learn: 0.6240571	total: 10.7s	remaining: 3m 9s
# 535:	learn: 0.6240503	total: 10.7s	remaining: 3m 9s
# 536:	learn: 0.6240380	total: 10.7s	remaining: 3m 8s
# 537:	learn: 0.6240354	total: 10.7s	remaining: 3m 8s
# 538:	learn: 0.6239988	total: 10.7s	remaining: 3m 8s
# 539:	learn: 0.6239844	total: 10.8s	remaining: 3m 8s
# 540:	learn: 0.6239734	total: 10.8s	remaining: 3m 8s
# 541:	learn: 0.6239455	total: 10.8s	remaining: 3m 8s
# 542:	learn: 0.6238926	total: 10.8s	remaining: 3m 8s
# 543:	learn: 0.6238392	total: 10.8s	remaining: 3m 8s
# 544:	learn: 0.6238089	total: 10.9s	remaining: 3m 8s
# 545:	learn: 0.6237830	total: 10.9s	remaining: 3m 8s
# 546:	learn: 0.6237671	total: 10.9s	remaining: 3m 8s
# 547:	learn: 0.6237504	total: 10.9s	remaining: 3m 8s
# 548:	learn: 0.6237250	total: 10.9s	remaining: 3m 8s
# 549:	learn: 0.6237250	total: 10.9s	remaining: 3m 8s
# 550:	learn: 0.6237238	total: 11s	remaining: 3m 7s
# 551:	learn: 0.6237102	total: 11s	remaining: 3m 7s
# 552:	learn: 0.6237051	total: 11s	remaining: 3m 7s
# 553:	learn: 0.6236953	total: 11s	remaining: 3m 8s
# 554:	learn: 0.6236880	total: 11.1s	remaining: 3m 8s
# 555:	learn: 0.6236594	total: 11.1s	remaining: 3m 8s
# 556:	learn: 0.6236395	total: 11.1s	remaining: 3m 8s
# 557:	learn: 0.6236348	total: 11.1s	remaining: 3m 8s
# 558:	learn: 0.6236077	total: 11.1s	remaining: 3m 8s
# 559:	learn: 0.6235676	total: 11.2s	remaining: 3m 8s
# 560:	learn: 0.6235580	total: 11.2s	remaining: 3m 7s
# 561:	learn: 0.6235521	total: 11.2s	remaining: 3m 7s
# 562:	learn: 0.6235410	total: 11.2s	remaining: 3m 7s
# 563:	learn: 0.6235350	total: 11.2s	remaining: 3m 7s
# 564:	learn: 0.6235204	total: 11.2s	remaining: 3m 7s
# 565:	learn: 0.6235173	total: 11.3s	remaining: 3m 7s
# 566:	learn: 0.6234949	total: 11.3s	remaining: 3m 7s
# 567:	learn: 0.6234820	total: 11.3s	remaining: 3m 7s
# 568:	learn: 0.6234631	total: 11.3s	remaining: 3m 7s
# 569:	learn: 0.6234442	total: 11.3s	remaining: 3m 7s
# 570:	learn: 0.6234287	total: 11.4s	remaining: 3m 7s
# 571:	learn: 0.6234165	total: 11.4s	remaining: 3m 7s
# 572:	learn: 0.6234016	total: 11.4s	remaining: 3m 7s
# 573:	learn: 0.6233757	total: 11.4s	remaining: 3m 7s
# 574:	learn: 0.6233538	total: 11.5s	remaining: 3m 8s
# 575:	learn: 0.6233357	total: 11.5s	remaining: 3m 8s
# 576:	learn: 0.6233128	total: 11.6s	remaining: 3m 8s
# 577:	learn: 0.6233002	total: 11.6s	remaining: 3m 8s
# 578:	learn: 0.6232796	total: 11.6s	remaining: 3m 8s
# 579:	learn: 0.6232395	total: 11.6s	remaining: 3m 8s
# 580:	learn: 0.6232162	total: 11.6s	remaining: 3m 8s
# 581:	learn: 0.6232063	total: 11.6s	remaining: 3m 8s
# 582:	learn: 0.6231903	total: 11.7s	remaining: 3m 8s
# 583:	learn: 0.6231506	total: 11.7s	remaining: 3m 8s
# 584:	learn: 0.6231477	total: 11.7s	remaining: 3m 8s
# 585:	learn: 0.6230915	total: 11.7s	remaining: 3m 8s
# 586:	learn: 0.6230698	total: 11.7s	remaining: 3m 8s
# 587:	learn: 0.6230570	total: 11.7s	remaining: 3m 8s
# 588:	learn: 0.6230507	total: 11.8s	remaining: 3m 7s
# 589:	learn: 0.6230441	total: 11.8s	remaining: 3m 7s
# 590:	learn: 0.6230285	total: 11.8s	remaining: 3m 7s
# 591:	learn: 0.6230139	total: 11.8s	remaining: 3m 7s
# 592:	learn: 0.6230068	total: 11.8s	remaining: 3m 7s
# 593:	learn: 0.6229891	total: 11.8s	remaining: 3m 7s
# 594:	learn: 0.6229775	total: 11.9s	remaining: 3m 7s
# 595:	learn: 0.6229630	total: 11.9s	remaining: 3m 7s
# 596:	learn: 0.6229567	total: 11.9s	remaining: 3m 7s
# 597:	learn: 0.6229279	total: 11.9s	remaining: 3m 7s
# 598:	learn: 0.6229164	total: 11.9s	remaining: 3m 7s
# 599:	learn: 0.6228836	total: 12s	remaining: 3m 7s
# 600:	learn: 0.6228642	total: 12s	remaining: 3m 7s
# 601:	learn: 0.6228536	total: 12s	remaining: 3m 7s
# 602:	learn: 0.6228086	total: 12s	remaining: 3m 6s
# 603:	learn: 0.6227928	total: 12s	remaining: 3m 6s
# 604:	learn: 0.6227725	total: 12s	remaining: 3m 6s
# 605:	learn: 0.6227693	total: 12s	remaining: 3m 6s
# 606:	learn: 0.6227662	total: 12.1s	remaining: 3m 6s
# 607:	learn: 0.6227559	total: 12.1s	remaining: 3m 6s
# 608:	learn: 0.6227507	total: 12.1s	remaining: 3m 6s
# 609:	learn: 0.6227435	total: 12.1s	remaining: 3m 6s
# 610:	learn: 0.6226900	total: 12.1s	remaining: 3m 6s
# 611:	learn: 0.6226687	total: 12.2s	remaining: 3m 6s
# 612:	learn: 0.6226493	total: 12.2s	remaining: 3m 6s
# 613:	learn: 0.6226404	total: 12.2s	remaining: 3m 6s
# 614:	learn: 0.6226342	total: 12.2s	remaining: 3m 6s
# 615:	learn: 0.6226188	total: 12.2s	remaining: 3m 6s
# 616:	learn: 0.6226140	total: 12.2s	remaining: 3m 6s
# 617:	learn: 0.6225888	total: 12.3s	remaining: 3m 6s
# 618:	learn: 0.6225619	total: 12.3s	remaining: 3m 5s
# 619:	learn: 0.6225390	total: 12.3s	remaining: 3m 5s
# 620:	learn: 0.6225304	total: 12.3s	remaining: 3m 5s
# 621:	learn: 0.6225218	total: 12.3s	remaining: 3m 5s
# 622:	learn: 0.6224908	total: 12.3s	remaining: 3m 5s
# 623:	learn: 0.6224854	total: 12.4s	remaining: 3m 5s
# 624:	learn: 0.6224817	total: 12.4s	remaining: 3m 5s
# 625:	learn: 0.6224663	total: 12.4s	remaining: 3m 5s
# 626:	learn: 0.6224518	total: 12.4s	remaining: 3m 5s
# 627:	learn: 0.6224318	total: 12.4s	remaining: 3m 5s
# 628:	learn: 0.6224238	total: 12.4s	remaining: 3m 5s
# 629:	learn: 0.6224159	total: 12.5s	remaining: 3m 5s
# 630:	learn: 0.6223841	total: 12.5s	remaining: 3m 5s
# 631:	learn: 0.6223762	total: 12.5s	remaining: 3m 5s
# 632:	learn: 0.6223483	total: 12.5s	remaining: 3m 5s
# 633:	learn: 0.6223118	total: 12.5s	remaining: 3m 5s
# 634:	learn: 0.6222991	total: 12.6s	remaining: 3m 5s
# 635:	learn: 0.6222753	total: 12.6s	remaining: 3m 5s
# 636:	learn: 0.6222669	total: 12.6s	remaining: 3m 5s
# 637:	learn: 0.6222616	total: 12.6s	remaining: 3m 4s
# 638:	learn: 0.6222435	total: 12.6s	remaining: 3m 4s
# 639:	learn: 0.6222388	total: 12.6s	remaining: 3m 4s
# 640:	learn: 0.6222326	total: 12.6s	remaining: 3m 4s
# 641:	learn: 0.6222164	total: 12.7s	remaining: 3m 4s
# 642:	learn: 0.6222008	total: 12.7s	remaining: 3m 4s
# 643:	learn: 0.6221853	total: 12.7s	remaining: 3m 4s
# 644:	learn: 0.6221764	total: 12.7s	remaining: 3m 4s
# 645:	learn: 0.6221596	total: 12.7s	remaining: 3m 4s
# 646:	learn: 0.6221387	total: 12.8s	remaining: 3m 4s
# 647:	learn: 0.6221234	total: 12.8s	remaining: 3m 4s
# 648:	learn: 0.6221201	total: 12.8s	remaining: 3m 4s
# 649:	learn: 0.6221140	total: 12.8s	remaining: 3m 4s
# 650:	learn: 0.6221050	total: 12.8s	remaining: 3m 4s
# 651:	learn: 0.6221018	total: 12.8s	remaining: 3m 3s
# 652:	learn: 0.6220989	total: 12.8s	remaining: 3m 3s
# 653:	learn: 0.6220872	total: 12.9s	remaining: 3m 3s
# 654:	learn: 0.6220801	total: 12.9s	remaining: 3m 3s
# 655:	learn: 0.6220759	total: 12.9s	remaining: 3m 3s
# 656:	learn: 0.6220721	total: 12.9s	remaining: 3m 3s
# 657:	learn: 0.6220611	total: 12.9s	remaining: 3m 3s
# 658:	learn: 0.6220554	total: 13s	remaining: 3m 3s
# 659:	learn: 0.6220202	total: 13s	remaining: 3m 3s
# 660:	learn: 0.6219971	total: 13s	remaining: 3m 3s
# 661:	learn: 0.6219869	total: 13s	remaining: 3m 3s
# 662:	learn: 0.6219786	total: 13s	remaining: 3m 3s
# 663:	learn: 0.6219506	total: 13s	remaining: 3m 3s
# 664:	learn: 0.6219499	total: 13.1s	remaining: 3m 3s
# 665:	learn: 0.6219163	total: 13.1s	remaining: 3m 3s
# 666:	learn: 0.6219100	total: 13.1s	remaining: 3m 3s
# 667:	learn: 0.6218906	total: 13.1s	remaining: 3m 3s
# 668:	learn: 0.6218643	total: 13.1s	remaining: 3m 3s
# 669:	learn: 0.6218609	total: 13.2s	remaining: 3m 3s
# 670:	learn: 0.6218527	total: 13.2s	remaining: 3m 3s
# 671:	learn: 0.6218281	total: 13.2s	remaining: 3m 3s
# 672:	learn: 0.6218183	total: 13.2s	remaining: 3m 3s
# 673:	learn: 0.6218103	total: 13.2s	remaining: 3m 2s
# 674:	learn: 0.6217887	total: 13.2s	remaining: 3m 2s
# 675:	learn: 0.6217488	total: 13.2s	remaining: 3m 2s
# 676:	learn: 0.6217431	total: 13.3s	remaining: 3m 2s
# 677:	learn: 0.6217285	total: 13.3s	remaining: 3m 2s
# 678:	learn: 0.6217158	total: 13.3s	remaining: 3m 2s
# 679:	learn: 0.6217086	total: 13.3s	remaining: 3m 2s
# 680:	learn: 0.6216967	total: 13.3s	remaining: 3m 2s
# 681:	learn: 0.6216805	total: 13.4s	remaining: 3m 2s
# 682:	learn: 0.6216775	total: 13.4s	remaining: 3m 2s
# 683:	learn: 0.6216759	total: 13.4s	remaining: 3m 2s
# 684:	learn: 0.6216697	total: 13.4s	remaining: 3m 2s
# 685:	learn: 0.6216592	total: 13.4s	remaining: 3m 2s
# 686:	learn: 0.6216566	total: 13.4s	remaining: 3m 2s
# 687:	learn: 0.6216414	total: 13.4s	remaining: 3m 1s
# 688:	learn: 0.6216193	total: 13.5s	remaining: 3m 1s
# 689:	learn: 0.6216036	total: 13.5s	remaining: 3m 1s
# 690:	learn: 0.6215983	total: 13.5s	remaining: 3m 1s
# 691:	learn: 0.6215895	total: 13.5s	remaining: 3m 1s
# 692:	learn: 0.6215844	total: 13.5s	remaining: 3m 1s
# 693:	learn: 0.6215806	total: 13.6s	remaining: 3m 1s
# 694:	learn: 0.6215693	total: 13.6s	remaining: 3m 1s
# 695:	learn: 0.6215547	total: 13.6s	remaining: 3m 1s
# 696:	learn: 0.6215400	total: 13.6s	remaining: 3m 1s
# 697:	learn: 0.6215329	total: 13.6s	remaining: 3m 1s
# 698:	learn: 0.6215229	total: 13.6s	remaining: 3m 1s
# 699:	learn: 0.6215170	total: 13.6s	remaining: 3m 1s
# 700:	learn: 0.6215095	total: 13.7s	remaining: 3m 1s
# 701:	learn: 0.6214792	total: 13.7s	remaining: 3m 1s
# 702:	learn: 0.6214685	total: 13.7s	remaining: 3m 1s
# 703:	learn: 0.6214473	total: 13.7s	remaining: 3m 1s
# 704:	learn: 0.6214473	total: 13.7s	remaining: 3m 1s
# 705:	learn: 0.6214410	total: 13.7s	remaining: 3m
# 706:	learn: 0.6214395	total: 13.8s	remaining: 3m
# 707:	learn: 0.6214010	total: 13.8s	remaining: 3m
# 708:	learn: 0.6213895	total: 13.8s	remaining: 3m
# 709:	learn: 0.6213539	total: 13.8s	remaining: 3m
# 710:	learn: 0.6213412	total: 13.8s	remaining: 3m
# 711:	learn: 0.6213321	total: 13.9s	remaining: 3m
# 712:	learn: 0.6213299	total: 13.9s	remaining: 3m
# 713:	learn: 0.6213075	total: 13.9s	remaining: 3m
# 714:	learn: 0.6213046	total: 13.9s	remaining: 3m
# 715:	learn: 0.6212965	total: 13.9s	remaining: 3m
# 716:	learn: 0.6212782	total: 13.9s	remaining: 3m
# 717:	learn: 0.6212681	total: 14s	remaining: 3m
# 718:	learn: 0.6212583	total: 14s	remaining: 3m
# 719:	learn: 0.6212498	total: 14s	remaining: 3m
# 720:	learn: 0.6212455	total: 14s	remaining: 3m
# 721:	learn: 0.6212250	total: 14s	remaining: 3m
# 722:	learn: 0.6212104	total: 14s	remaining: 3m
# 723:	learn: 0.6212004	total: 14.1s	remaining: 3m
# 724:	learn: 0.6211861	total: 14.1s	remaining: 3m
# 725:	learn: 0.6211827	total: 14.1s	remaining: 2m 59s
# 726:	learn: 0.6211827	total: 14.1s	remaining: 2m 59s
# 727:	learn: 0.6211697	total: 14.1s	remaining: 2m 59s
# 728:	learn: 0.6211625	total: 14.1s	remaining: 2m 59s
# 729:	learn: 0.6211554	total: 14.2s	remaining: 2m 59s
# 730:	learn: 0.6211474	total: 14.2s	remaining: 2m 59s
# 731:	learn: 0.6211455	total: 14.2s	remaining: 2m 59s
# 732:	learn: 0.6211351	total: 14.2s	remaining: 2m 59s
# 733:	learn: 0.6211302	total: 14.2s	remaining: 2m 59s
# 734:	learn: 0.6211229	total: 14.2s	remaining: 2m 59s
# 735:	learn: 0.6211100	total: 14.3s	remaining: 2m 59s
# 736:	learn: 0.6211056	total: 14.3s	remaining: 2m 59s
# 737:	learn: 0.6210947	total: 14.4s	remaining: 3m
# 738:	learn: 0.6210895	total: 14.4s	remaining: 3m
# 739:	learn: 0.6210725	total: 14.4s	remaining: 3m
# 740:	learn: 0.6210607	total: 14.4s	remaining: 3m
# 741:	learn: 0.6210562	total: 14.5s	remaining: 3m
# 742:	learn: 0.6210474	total: 14.5s	remaining: 3m
# 743:	learn: 0.6210273	total: 14.5s	remaining: 3m
# 744:	learn: 0.6210222	total: 14.5s	remaining: 3m
# 745:	learn: 0.6210159	total: 14.5s	remaining: 2m 59s
# 746:	learn: 0.6210098	total: 14.5s	remaining: 2m 59s
# 747:	learn: 0.6209971	total: 14.5s	remaining: 2m 59s
# 748:	learn: 0.6209762	total: 14.6s	remaining: 2m 59s
# 749:	learn: 0.6209721	total: 14.6s	remaining: 2m 59s
# 750:	learn: 0.6209304	total: 14.6s	remaining: 2m 59s
# 751:	learn: 0.6209266	total: 14.6s	remaining: 2m 59s
# 752:	learn: 0.6209214	total: 14.6s	remaining: 2m 59s
# 753:	learn: 0.6209080	total: 14.7s	remaining: 2m 59s
# 754:	learn: 0.6208866	total: 14.7s	remaining: 2m 59s
# 755:	learn: 0.6208803	total: 14.7s	remaining: 2m 59s
# 756:	learn: 0.6208723	total: 14.7s	remaining: 2m 59s
# 757:	learn: 0.6208471	total: 14.7s	remaining: 2m 59s
# 758:	learn: 0.6208462	total: 14.7s	remaining: 2m 59s
# 759:	learn: 0.6208429	total: 14.7s	remaining: 2m 59s
# 760:	learn: 0.6208054	total: 14.8s	remaining: 2m 59s
# 761:	learn: 0.6207964	total: 14.8s	remaining: 2m 59s
# 762:	learn: 0.6207922	total: 14.8s	remaining: 2m 59s
# 763:	learn: 0.6207799	total: 14.8s	remaining: 2m 59s
# 764:	learn: 0.6207750	total: 14.8s	remaining: 2m 59s
# 765:	learn: 0.6207629	total: 14.9s	remaining: 2m 59s
# 766:	learn: 0.6207507	total: 14.9s	remaining: 2m 59s
# 767:	learn: 0.6207436	total: 14.9s	remaining: 2m 59s
# 768:	learn: 0.6207338	total: 14.9s	remaining: 2m 58s
# 769:	learn: 0.6207183	total: 14.9s	remaining: 2m 58s
# 770:	learn: 0.6207072	total: 14.9s	remaining: 2m 58s
# 771:	learn: 0.6206758	total: 14.9s	remaining: 2m 58s
# 772:	learn: 0.6206685	total: 15s	remaining: 2m 58s
# 773:	learn: 0.6206631	total: 15s	remaining: 2m 58s
# 774:	learn: 0.6206597	total: 15s	remaining: 2m 58s
# 775:	learn: 0.6206570	total: 15s	remaining: 2m 58s
# 776:	learn: 0.6206519	total: 15s	remaining: 2m 58s
# 777:	learn: 0.6206460	total: 15.1s	remaining: 2m 58s
# 778:	learn: 0.6206424	total: 15.1s	remaining: 2m 58s
# 779:	learn: 0.6206332	total: 15.2s	remaining: 2m 59s
# 780:	learn: 0.6206288	total: 15.2s	remaining: 2m 59s
# 781:	learn: 0.6206270	total: 15.2s	remaining: 2m 59s
# 782:	learn: 0.6206207	total: 15.2s	remaining: 2m 59s
# 783:	learn: 0.6206179	total: 15.3s	remaining: 2m 59s
# 784:	learn: 0.6206022	total: 15.3s	remaining: 2m 59s
# 785:	learn: 0.6205934	total: 15.3s	remaining: 2m 59s
# 786:	learn: 0.6205886	total: 15.3s	remaining: 2m 59s
# 787:	learn: 0.6205800	total: 15.3s	remaining: 2m 59s
# 788:	learn: 0.6205768	total: 15.3s	remaining: 2m 59s
# 789:	learn: 0.6205609	total: 15.4s	remaining: 2m 59s
# 790:	learn: 0.6205566	total: 15.4s	remaining: 2m 58s
# 791:	learn: 0.6205487	total: 15.4s	remaining: 2m 58s
# 792:	learn: 0.6205426	total: 15.4s	remaining: 2m 58s
# 793:	learn: 0.6205364	total: 15.4s	remaining: 2m 58s
# 794:	learn: 0.6205283	total: 15.4s	remaining: 2m 58s
# 795:	learn: 0.6205270	total: 15.5s	remaining: 2m 58s
# 796:	learn: 0.6205124	total: 15.5s	remaining: 2m 58s
# 797:	learn: 0.6205073	total: 15.5s	remaining: 2m 58s
# 798:	learn: 0.6205040	total: 15.5s	remaining: 2m 58s
# 799:	learn: 0.6204989	total: 15.5s	remaining: 2m 58s
# 800:	learn: 0.6204985	total: 15.5s	remaining: 2m 58s
# 801:	learn: 0.6204949	total: 15.6s	remaining: 2m 58s
# 802:	learn: 0.6204940	total: 15.6s	remaining: 2m 58s
# 803:	learn: 0.6204908	total: 15.6s	remaining: 2m 58s
# 804:	learn: 0.6204897	total: 15.6s	remaining: 2m 58s
# 805:	learn: 0.6204841	total: 15.6s	remaining: 2m 58s
# 806:	learn: 0.6204824	total: 15.6s	remaining: 2m 57s
# 807:	learn: 0.6204783	total: 15.6s	remaining: 2m 57s
# 808:	learn: 0.6204751	total: 15.7s	remaining: 2m 57s
# 809:	learn: 0.6204607	total: 15.7s	remaining: 2m 57s
# 810:	learn: 0.6204531	total: 15.7s	remaining: 2m 57s
# 811:	learn: 0.6204493	total: 15.7s	remaining: 2m 57s
# 812:	learn: 0.6204454	total: 15.7s	remaining: 2m 57s
# 813:	learn: 0.6204103	total: 15.8s	remaining: 2m 57s
# 814:	learn: 0.6203492	total: 15.8s	remaining: 2m 57s
# 815:	learn: 0.6203415	total: 15.8s	remaining: 2m 57s
# 816:	learn: 0.6203377	total: 15.8s	remaining: 2m 57s
# 817:	learn: 0.6203222	total: 15.8s	remaining: 2m 57s
# 818:	learn: 0.6203105	total: 15.8s	remaining: 2m 57s
# 819:	learn: 0.6203065	total: 15.8s	remaining: 2m 57s
# 820:	learn: 0.6203007	total: 15.9s	remaining: 2m 57s
# 821:	learn: 0.6202989	total: 15.9s	remaining: 2m 57s
# 822:	learn: 0.6202886	total: 15.9s	remaining: 2m 57s
# 823:	learn: 0.6202836	total: 15.9s	remaining: 2m 57s
# 824:	learn: 0.6202778	total: 15.9s	remaining: 2m 57s
# 825:	learn: 0.6202714	total: 16s	remaining: 2m 57s
# 826:	learn: 0.6202668	total: 16s	remaining: 2m 57s
# 827:	learn: 0.6202653	total: 16s	remaining: 2m 57s
# 828:	learn: 0.6202617	total: 16s	remaining: 2m 57s
# 829:	learn: 0.6202520	total: 16s	remaining: 2m 57s
# 830:	learn: 0.6202422	total: 16s	remaining: 2m 56s
# 831:	learn: 0.6202385	total: 16s	remaining: 2m 56s
# 832:	learn: 0.6202056	total: 16.1s	remaining: 2m 56s
# 833:	learn: 0.6202024	total: 16.1s	remaining: 2m 56s
# 834:	learn: 0.6201889	total: 16.1s	remaining: 2m 56s
# 835:	learn: 0.6201837	total: 16.1s	remaining: 2m 56s
# 836:	learn: 0.6201828	total: 16.1s	remaining: 2m 56s
# 837:	learn: 0.6201808	total: 16.2s	remaining: 2m 56s
# 838:	learn: 0.6201658	total: 16.2s	remaining: 2m 56s
# 839:	learn: 0.6201609	total: 16.2s	remaining: 2m 56s
# 840:	learn: 0.6201606	total: 16.2s	remaining: 2m 56s
# 841:	learn: 0.6201601	total: 16.2s	remaining: 2m 56s
# 842:	learn: 0.6201566	total: 16.2s	remaining: 2m 56s
# 843:	learn: 0.6201528	total: 16.3s	remaining: 2m 56s
# 844:	learn: 0.6201367	total: 16.3s	remaining: 2m 56s
# 845:	learn: 0.6201283	total: 16.3s	remaining: 2m 56s
# 846:	learn: 0.6201084	total: 16.3s	remaining: 2m 56s
# 847:	learn: 0.6201040	total: 16.3s	remaining: 2m 56s
# 848:	learn: 0.6200763	total: 16.3s	remaining: 2m 56s
# 849:	learn: 0.6200637	total: 16.4s	remaining: 2m 56s
# 850:	learn: 0.6200588	total: 16.4s	remaining: 2m 56s
# 851:	learn: 0.6200543	total: 16.4s	remaining: 2m 56s
# 852:	learn: 0.6200465	total: 16.4s	remaining: 2m 56s
# 853:	learn: 0.6200362	total: 16.4s	remaining: 2m 55s
# 854:	learn: 0.6200305	total: 16.4s	remaining: 2m 55s
# 855:	learn: 0.6200305	total: 16.4s	remaining: 2m 55s
# 856:	learn: 0.6199942	total: 16.5s	remaining: 2m 55s
# 857:	learn: 0.6199911	total: 16.5s	remaining: 2m 55s
# 858:	learn: 0.6199849	total: 16.5s	remaining: 2m 55s
# 859:	learn: 0.6199644	total: 16.5s	remaining: 2m 55s
# 860:	learn: 0.6199620	total: 16.6s	remaining: 2m 55s
# 861:	learn: 0.6199551	total: 16.6s	remaining: 2m 55s
# 862:	learn: 0.6199526	total: 16.6s	remaining: 2m 55s
# 863:	learn: 0.6199524	total: 16.6s	remaining: 2m 55s
# 864:	learn: 0.6199510	total: 16.6s	remaining: 2m 55s
# 865:	learn: 0.6199509	total: 16.6s	remaining: 2m 55s
# 866:	learn: 0.6199310	total: 16.6s	remaining: 2m 55s
# 867:	learn: 0.6199211	total: 16.6s	remaining: 2m 55s
# 868:	learn: 0.6199138	total: 16.7s	remaining: 2m 55s
# 869:	learn: 0.6199079	total: 16.7s	remaining: 2m 55s
# 870:	learn: 0.6199075	total: 16.7s	remaining: 2m 55s
# 871:	learn: 0.6199055	total: 16.7s	remaining: 2m 55s
# 872:	learn: 0.6198782	total: 16.7s	remaining: 2m 54s
# 873:	learn: 0.6198747	total: 16.8s	remaining: 2m 54s
# 874:	learn: 0.6198648	total: 16.8s	remaining: 2m 54s
# 875:	learn: 0.6198635	total: 16.8s	remaining: 2m 54s
# 876:	learn: 0.6198597	total: 16.8s	remaining: 2m 54s
# 877:	learn: 0.6198525	total: 16.8s	remaining: 2m 54s
# 878:	learn: 0.6198476	total: 16.9s	remaining: 2m 55s
# 879:	learn: 0.6198457	total: 16.9s	remaining: 2m 55s
# 880:	learn: 0.6198369	total: 17s	remaining: 2m 55s
# 881:	learn: 0.6197795	total: 17s	remaining: 2m 55s
# 882:	learn: 0.6197619	total: 17s	remaining: 2m 55s
# 883:	learn: 0.6197447	total: 17s	remaining: 2m 55s
# 884:	learn: 0.6197443	total: 17s	remaining: 2m 55s
# 885:	learn: 0.6197403	total: 17.1s	remaining: 2m 55s
# 886:	learn: 0.6197391	total: 17.1s	remaining: 2m 55s
# 887:	learn: 0.6197324	total: 17.1s	remaining: 2m 55s
# 888:	learn: 0.6197292	total: 17.1s	remaining: 2m 55s
# 889:	learn: 0.6197224	total: 17.1s	remaining: 2m 55s
# 890:	learn: 0.6197044	total: 17.1s	remaining: 2m 55s
# 891:	learn: 0.6196953	total: 17.2s	remaining: 2m 55s
# 892:	learn: 0.6196682	total: 17.2s	remaining: 2m 55s
# 893:	learn: 0.6196526	total: 17.2s	remaining: 2m 55s
# 894:	learn: 0.6196495	total: 17.2s	remaining: 2m 55s
# 895:	learn: 0.6196490	total: 17.2s	remaining: 2m 55s
# 896:	learn: 0.6196484	total: 17.2s	remaining: 2m 55s
# 897:	learn: 0.6196456	total: 17.3s	remaining: 2m 54s
# 898:	learn: 0.6196389	total: 17.3s	remaining: 2m 54s
# 899:	learn: 0.6196389	total: 17.3s	remaining: 2m 54s
# 900:	learn: 0.6196297	total: 17.3s	remaining: 2m 54s
# 901:	learn: 0.6196294	total: 17.3s	remaining: 2m 54s
# 902:	learn: 0.6196050	total: 17.3s	remaining: 2m 54s
# 903:	learn: 0.6196015	total: 17.4s	remaining: 2m 54s
# 904:	learn: 0.6195876	total: 17.4s	remaining: 2m 54s
# 905:	learn: 0.6195846	total: 17.4s	remaining: 2m 54s
# 906:	learn: 0.6195822	total: 17.4s	remaining: 2m 54s
# 907:	learn: 0.6195801	total: 17.4s	remaining: 2m 54s
# 908:	learn: 0.6195747	total: 17.4s	remaining: 2m 54s
# 909:	learn: 0.6195631	total: 17.5s	remaining: 2m 54s
# 910:	learn: 0.6195559	total: 17.5s	remaining: 2m 54s
# 911:	learn: 0.6195549	total: 17.5s	remaining: 2m 54s
# 912:	learn: 0.6195493	total: 17.5s	remaining: 2m 54s
# 913:	learn: 0.6195445	total: 17.5s	remaining: 2m 54s
# 914:	learn: 0.6195387	total: 17.5s	remaining: 2m 54s
# ...
# 9726:	learn: 0.6146291	total: 2m 27s	remaining: 4.14s
# 9727:	learn: 0.6146286	total: 2m 27s	remaining: 4.12s
# 9728:	learn: 0.6146286	total: 2m 27s	remaining: 4.11s
# 9729:	learn: 0.6146286	total: 2m 27s	remaining: 4.09s
# 9730:	learn: 0.6146286	total: 2m 27s	remaining: 4.08s
# 9731:	learn: 0.6146286	total: 2m 27s	remaining: 4.06s
# 9732:	learn: 0.6146286	total: 2m 27s	remaining: 4.04s
# 9733:	learn: 0.6146286	total: 2m 27s	remaining: 4.03s
# 9734:	learn: 0.6146286	total: 2m 27s	remaining: 4.01s
# 9735:	learn: 0.6146286	total: 2m 27s	remaining: 4s
# 9736:	learn: 0.6146286	total: 2m 27s	remaining: 3.98s
# 9737:	learn: 0.6146286	total: 2m 27s	remaining: 3.97s
# 9738:	learn: 0.6146286	total: 2m 27s	remaining: 3.95s
# 9739:	learn: 0.6146285	total: 2m 27s	remaining: 3.94s
# 9740:	learn: 0.6146285	total: 2m 27s	remaining: 3.92s
# 9741:	learn: 0.6146285	total: 2m 27s	remaining: 3.91s
# 9742:	learn: 0.6146285	total: 2m 27s	remaining: 3.89s
# 9743:	learn: 0.6146285	total: 2m 27s	remaining: 3.88s
# 9744:	learn: 0.6146284	total: 2m 27s	remaining: 3.86s
# 9745:	learn: 0.6146284	total: 2m 27s	remaining: 3.85s
# 9746:	learn: 0.6146284	total: 2m 27s	remaining: 3.83s
# 9747:	learn: 0.6146284	total: 2m 27s	remaining: 3.82s
# 9748:	learn: 0.6146284	total: 2m 27s	remaining: 3.8s
# 9749:	learn: 0.6146284	total: 2m 27s	remaining: 3.79s
# 9750:	learn: 0.6146283	total: 2m 27s	remaining: 3.77s
# 9751:	learn: 0.6146283	total: 2m 27s	remaining: 3.76s
# 9752:	learn: 0.6146283	total: 2m 27s	remaining: 3.74s
# 9753:	learn: 0.6146283	total: 2m 27s	remaining: 3.73s
# 9754:	learn: 0.6146282	total: 2m 27s	remaining: 3.71s
# 9755:	learn: 0.6146282	total: 2m 27s	remaining: 3.7s
# 9756:	learn: 0.6146282	total: 2m 27s	remaining: 3.68s
# 9757:	learn: 0.6146282	total: 2m 27s	remaining: 3.67s
# 9758:	learn: 0.6146282	total: 2m 27s	remaining: 3.65s
# 9759:	learn: 0.6146282	total: 2m 27s	remaining: 3.64s
# 9760:	learn: 0.6146282	total: 2m 27s	remaining: 3.62s
# 9761:	learn: 0.6146281	total: 2m 27s	remaining: 3.6s
# 9762:	learn: 0.6146281	total: 2m 27s	remaining: 3.59s
# 9763:	learn: 0.6146281	total: 2m 27s	remaining: 3.58s
# 9764:	learn: 0.6146281	total: 2m 27s	remaining: 3.56s
# 9765:	learn: 0.6146280	total: 2m 27s	remaining: 3.54s
# 9766:	learn: 0.6146280	total: 2m 27s	remaining: 3.53s
# 9767:	learn: 0.6146280	total: 2m 27s	remaining: 3.51s
# 9768:	learn: 0.6146280	total: 2m 27s	remaining: 3.5s
# 9769:	learn: 0.6146280	total: 2m 28s	remaining: 3.48s
# 9770:	learn: 0.6146280	total: 2m 28s	remaining: 3.47s
# 9771:	learn: 0.6146280	total: 2m 28s	remaining: 3.45s
# 9772:	learn: 0.6146280	total: 2m 28s	remaining: 3.44s
# 9773:	learn: 0.6146280	total: 2m 28s	remaining: 3.42s
# 9774:	learn: 0.6146280	total: 2m 28s	remaining: 3.41s
# 9775:	learn: 0.6146279	total: 2m 28s	remaining: 3.39s
# 9776:	learn: 0.6146279	total: 2m 28s	remaining: 3.38s
# 9777:	learn: 0.6146279	total: 2m 28s	remaining: 3.36s
# 9778:	learn: 0.6146279	total: 2m 28s	remaining: 3.35s
# 9779:	learn: 0.6146278	total: 2m 28s	remaining: 3.33s
# 9780:	learn: 0.6146278	total: 2m 28s	remaining: 3.32s
# 9781:	learn: 0.6146278	total: 2m 28s	remaining: 3.3s
# 9782:	learn: 0.6146278	total: 2m 28s	remaining: 3.29s
# 9783:	learn: 0.6146278	total: 2m 28s	remaining: 3.27s
# 9784:	learn: 0.6146278	total: 2m 28s	remaining: 3.26s
# 9785:	learn: 0.6146277	total: 2m 28s	remaining: 3.24s
# 9786:	learn: 0.6146277	total: 2m 28s	remaining: 3.23s
# 9787:	learn: 0.6146277	total: 2m 28s	remaining: 3.21s
# 9788:	learn: 0.6146277	total: 2m 28s	remaining: 3.2s
# 9789:	learn: 0.6146277	total: 2m 28s	remaining: 3.18s
# 9790:	learn: 0.6146277	total: 2m 28s	remaining: 3.17s
# 9791:	learn: 0.6146276	total: 2m 28s	remaining: 3.15s
# 9792:	learn: 0.6146276	total: 2m 28s	remaining: 3.13s
# 9793:	learn: 0.6146276	total: 2m 28s	remaining: 3.12s
# 9794:	learn: 0.6146276	total: 2m 28s	remaining: 3.1s
# 9795:	learn: 0.6146274	total: 2m 28s	remaining: 3.09s
# 9796:	learn: 0.6146274	total: 2m 28s	remaining: 3.08s
# 9797:	learn: 0.6146274	total: 2m 28s	remaining: 3.06s
# 9798:	learn: 0.6146274	total: 2m 28s	remaining: 3.05s
# 9799:	learn: 0.6146274	total: 2m 28s	remaining: 3.03s
# 9800:	learn: 0.6146274	total: 2m 28s	remaining: 3.02s
# 9801:	learn: 0.6146274	total: 2m 28s	remaining: 3s
# 9802:	learn: 0.6146274	total: 2m 28s	remaining: 2.99s
# 9803:	learn: 0.6146274	total: 2m 28s	remaining: 2.97s
# 9804:	learn: 0.6146273	total: 2m 28s	remaining: 2.96s
# 9805:	learn: 0.6146273	total: 2m 28s	remaining: 2.94s
# 9806:	learn: 0.6146273	total: 2m 28s	remaining: 2.92s
# 9807:	learn: 0.6146273	total: 2m 28s	remaining: 2.91s
# 9808:	learn: 0.6146273	total: 2m 28s	remaining: 2.9s
# 9809:	learn: 0.6146273	total: 2m 28s	remaining: 2.88s
# 9810:	learn: 0.6146273	total: 2m 28s	remaining: 2.87s
# 9811:	learn: 0.6146272	total: 2m 28s	remaining: 2.85s
# 9812:	learn: 0.6146272	total: 2m 28s	remaining: 2.83s
# 9813:	learn: 0.6146272	total: 2m 28s	remaining: 2.82s
# 9814:	learn: 0.6146272	total: 2m 28s	remaining: 2.8s
# 9815:	learn: 0.6146272	total: 2m 28s	remaining: 2.79s
# 9816:	learn: 0.6146272	total: 2m 28s	remaining: 2.77s
# 9817:	learn: 0.6146272	total: 2m 28s	remaining: 2.76s
# 9818:	learn: 0.6146272	total: 2m 28s	remaining: 2.74s
# 9819:	learn: 0.6146271	total: 2m 28s	remaining: 2.73s
# 9820:	learn: 0.6146271	total: 2m 28s	remaining: 2.71s
# 9821:	learn: 0.6146271	total: 2m 28s	remaining: 2.7s
# 9822:	learn: 0.6146271	total: 2m 28s	remaining: 2.68s
# 9823:	learn: 0.6146269	total: 2m 28s	remaining: 2.67s
# 9824:	learn: 0.6146269	total: 2m 28s	remaining: 2.65s
# 9825:	learn: 0.6146268	total: 2m 28s	remaining: 2.64s
# 9826:	learn: 0.6146268	total: 2m 28s	remaining: 2.62s
# 9827:	learn: 0.6146266	total: 2m 29s	remaining: 2.61s
# 9828:	learn: 0.6146266	total: 2m 29s	remaining: 2.59s
# 9829:	learn: 0.6146266	total: 2m 29s	remaining: 2.58s
# 9830:	learn: 0.6146266	total: 2m 29s	remaining: 2.56s
# 9831:	learn: 0.6146266	total: 2m 29s	remaining: 2.55s
# 9832:	learn: 0.6146266	total: 2m 29s	remaining: 2.53s
# 9833:	learn: 0.6146266	total: 2m 29s	remaining: 2.52s
# 9834:	learn: 0.6146266	total: 2m 29s	remaining: 2.5s
# 9835:	learn: 0.6146266	total: 2m 29s	remaining: 2.49s
# 9836:	learn: 0.6146266	total: 2m 29s	remaining: 2.47s
# 9837:	learn: 0.6146265	total: 2m 29s	remaining: 2.46s
# 9838:	learn: 0.6146261	total: 2m 29s	remaining: 2.44s
# 9839:	learn: 0.6146261	total: 2m 29s	remaining: 2.42s
# 9840:	learn: 0.6146261	total: 2m 29s	remaining: 2.41s
# 9841:	learn: 0.6146261	total: 2m 29s	remaining: 2.4s
# 9842:	learn: 0.6146260	total: 2m 29s	remaining: 2.38s
# 9843:	learn: 0.6146260	total: 2m 29s	remaining: 2.37s
# 9844:	learn: 0.6146259	total: 2m 29s	remaining: 2.35s
# 9845:	learn: 0.6146259	total: 2m 29s	remaining: 2.33s
# 9846:	learn: 0.6146258	total: 2m 29s	remaining: 2.32s
# 9847:	learn: 0.6146258	total: 2m 29s	remaining: 2.3s
# 9848:	learn: 0.6146258	total: 2m 29s	remaining: 2.29s
# 9849:	learn: 0.6146258	total: 2m 29s	remaining: 2.27s
# 9850:	learn: 0.6146258	total: 2m 29s	remaining: 2.26s
# 9851:	learn: 0.6146258	total: 2m 29s	remaining: 2.24s
# 9852:	learn: 0.6146258	total: 2m 29s	remaining: 2.23s
# 9853:	learn: 0.6146258	total: 2m 29s	remaining: 2.21s
# 9854:	learn: 0.6146258	total: 2m 29s	remaining: 2.2s
# 9855:	learn: 0.6146258	total: 2m 29s	remaining: 2.18s
# 9856:	learn: 0.6146258	total: 2m 29s	remaining: 2.17s
# 9857:	learn: 0.6146258	total: 2m 29s	remaining: 2.15s
# 9858:	learn: 0.6146258	total: 2m 29s	remaining: 2.14s
# 9859:	learn: 0.6146258	total: 2m 29s	remaining: 2.12s
# 9860:	learn: 0.6146258	total: 2m 29s	remaining: 2.11s
# 9861:	learn: 0.6146258	total: 2m 29s	remaining: 2.09s
# 9862:	learn: 0.6146258	total: 2m 29s	remaining: 2.08s
# 9863:	learn: 0.6146258	total: 2m 29s	remaining: 2.06s
# 9864:	learn: 0.6146258	total: 2m 29s	remaining: 2.05s
# 9865:	learn: 0.6146257	total: 2m 29s	remaining: 2.03s
# 9866:	learn: 0.6146257	total: 2m 29s	remaining: 2.02s
# 9867:	learn: 0.6146257	total: 2m 29s	remaining: 2s
# 9868:	learn: 0.6146257	total: 2m 29s	remaining: 1.99s
# 9869:	learn: 0.6146257	total: 2m 29s	remaining: 1.97s
# 9870:	learn: 0.6146256	total: 2m 29s	remaining: 1.96s
# 9871:	learn: 0.6146252	total: 2m 29s	remaining: 1.94s
# 9872:	learn: 0.6146252	total: 2m 29s	remaining: 1.93s
# 9873:	learn: 0.6146251	total: 2m 29s	remaining: 1.91s
# 9874:	learn: 0.6146251	total: 2m 29s	remaining: 1.9s
# 9875:	learn: 0.6146250	total: 2m 29s	remaining: 1.88s
# 9876:	learn: 0.6146250	total: 2m 29s	remaining: 1.86s
# 9877:	learn: 0.6146250	total: 2m 29s	remaining: 1.85s
# 9878:	learn: 0.6146250	total: 2m 29s	remaining: 1.83s
# 9879:	learn: 0.6146249	total: 2m 29s	remaining: 1.82s
# 9880:	learn: 0.6146249	total: 2m 29s	remaining: 1.8s
# 9881:	learn: 0.6146249	total: 2m 29s	remaining: 1.79s
# 9882:	learn: 0.6146249	total: 2m 29s	remaining: 1.77s
# 9883:	learn: 0.6146249	total: 2m 29s	remaining: 1.76s
# 9884:	learn: 0.6146249	total: 2m 29s	remaining: 1.74s
# 9885:	learn: 0.6146249	total: 2m 29s	remaining: 1.73s
# 9886:	learn: 0.6146249	total: 2m 29s	remaining: 1.71s
# 9887:	learn: 0.6146249	total: 2m 30s	remaining: 1.7s
# 9888:	learn: 0.6146249	total: 2m 30s	remaining: 1.68s
# 9889:	learn: 0.6146249	total: 2m 30s	remaining: 1.67s
# 9890:	learn: 0.6146248	total: 2m 30s	remaining: 1.65s
# 9891:	learn: 0.6146248	total: 2m 30s	remaining: 1.64s
# 9892:	learn: 0.6146248	total: 2m 30s	remaining: 1.62s
# 9893:	learn: 0.6146248	total: 2m 30s	remaining: 1.61s
# 9894:	learn: 0.6146248	total: 2m 30s	remaining: 1.59s
# 9895:	learn: 0.6146248	total: 2m 30s	remaining: 1.58s
# 9896:	learn: 0.6146248	total: 2m 30s	remaining: 1.56s
# 9897:	learn: 0.6146248	total: 2m 30s	remaining: 1.55s
# 9898:	learn: 0.6146248	total: 2m 30s	remaining: 1.53s
# 9899:	learn: 0.6146247	total: 2m 30s	remaining: 1.52s
# 9900:	learn: 0.6146247	total: 2m 30s	remaining: 1.5s
# 9901:	learn: 0.6146247	total: 2m 30s	remaining: 1.49s
# 9902:	learn: 0.6146247	total: 2m 30s	remaining: 1.47s
# 9903:	learn: 0.6146247	total: 2m 30s	remaining: 1.46s
# 9904:	learn: 0.6146247	total: 2m 30s	remaining: 1.44s
# 9905:	learn: 0.6146247	total: 2m 30s	remaining: 1.43s
# 9906:	learn: 0.6146247	total: 2m 30s	remaining: 1.41s
# 9907:	learn: 0.6146246	total: 2m 30s	remaining: 1.4s
# 9908:	learn: 0.6146246	total: 2m 30s	remaining: 1.38s
# 9909:	learn: 0.6146246	total: 2m 30s	remaining: 1.37s
# 9910:	learn: 0.6146246	total: 2m 30s	remaining: 1.35s
# 9911:	learn: 0.6146246	total: 2m 30s	remaining: 1.33s
# 9912:	learn: 0.6146245	total: 2m 30s	remaining: 1.32s
# 9913:	learn: 0.6146245	total: 2m 30s	remaining: 1.3s
# 9914:	learn: 0.6146245	total: 2m 30s	remaining: 1.29s
# 9915:	learn: 0.6146245	total: 2m 30s	remaining: 1.27s
# 9916:	learn: 0.6146245	total: 2m 30s	remaining: 1.26s
# 9917:	learn: 0.6146245	total: 2m 30s	remaining: 1.24s
# 9918:	learn: 0.6146245	total: 2m 30s	remaining: 1.23s
# 9919:	learn: 0.6146245	total: 2m 30s	remaining: 1.21s
# 9920:	learn: 0.6146245	total: 2m 30s	remaining: 1.2s
# 9921:	learn: 0.6146245	total: 2m 30s	remaining: 1.18s
# 9922:	learn: 0.6146244	total: 2m 30s	remaining: 1.17s
# 9923:	learn: 0.6146243	total: 2m 30s	remaining: 1.15s
# 9924:	learn: 0.6146243	total: 2m 30s	remaining: 1.14s
# 9925:	learn: 0.6146243	total: 2m 30s	remaining: 1.12s
# 9926:	learn: 0.6146243	total: 2m 30s	remaining: 1.11s
# 9927:	learn: 0.6146243	total: 2m 30s	remaining: 1.09s
# 9928:	learn: 0.6146243	total: 2m 30s	remaining: 1.08s
# 9929:	learn: 0.6146243	total: 2m 30s	remaining: 1.06s
# 9930:	learn: 0.6146243	total: 2m 30s	remaining: 1.05s
# 9931:	learn: 0.6146243	total: 2m 30s	remaining: 1.03s
# 9932:	learn: 0.6146243	total: 2m 30s	remaining: 1.02s
# 9933:	learn: 0.6146243	total: 2m 30s	remaining: 1s
# 9934:	learn: 0.6146243	total: 2m 30s	remaining: 987ms
# 9935:	learn: 0.6146243	total: 2m 30s	remaining: 971ms
# 9936:	learn: 0.6146243	total: 2m 30s	remaining: 956ms
# 9937:	learn: 0.6146243	total: 2m 30s	remaining: 941ms
# 9938:	learn: 0.6146243	total: 2m 30s	remaining: 926ms
# 9939:	learn: 0.6146242	total: 2m 30s	remaining: 911ms
# 9940:	learn: 0.6146242	total: 2m 30s	remaining: 896ms
# 9941:	learn: 0.6146242	total: 2m 30s	remaining: 880ms
# 9942:	learn: 0.6146242	total: 2m 30s	remaining: 865ms
# 9943:	learn: 0.6146242	total: 2m 30s	remaining: 850ms
# 9944:	learn: 0.6146242	total: 2m 30s	remaining: 835ms
# 9945:	learn: 0.6146242	total: 2m 30s	remaining: 820ms
# 9946:	learn: 0.6146242	total: 2m 30s	remaining: 804ms
# 9947:	learn: 0.6146242	total: 2m 30s	remaining: 789ms
# 9948:	learn: 0.6146242	total: 2m 31s	remaining: 774ms
# 9949:	learn: 0.6146242	total: 2m 31s	remaining: 759ms
# 9950:	learn: 0.6146242	total: 2m 31s	remaining: 744ms
# 9951:	learn: 0.6146242	total: 2m 31s	remaining: 729ms
# 9952:	learn: 0.6146242	total: 2m 31s	remaining: 713ms
# 9953:	learn: 0.6146241	total: 2m 31s	remaining: 698ms
# 9954:	learn: 0.6146241	total: 2m 31s	remaining: 683ms
# 9955:	learn: 0.6146241	total: 2m 31s	remaining: 668ms
# 9956:	learn: 0.6146241	total: 2m 31s	remaining: 653ms
# 9957:	learn: 0.6146241	total: 2m 31s	remaining: 637ms
# 9958:	learn: 0.6146241	total: 2m 31s	remaining: 622ms
# 9959:	learn: 0.6146240	total: 2m 31s	remaining: 607ms
# 9960:	learn: 0.6146240	total: 2m 31s	remaining: 592ms
# 9961:	learn: 0.6146240	total: 2m 31s	remaining: 577ms
# 9962:	learn: 0.6146240	total: 2m 31s	remaining: 562ms
# 9963:	learn: 0.6146240	total: 2m 31s	remaining: 546ms
# 9964:	learn: 0.6146240	total: 2m 31s	remaining: 531ms
# 9965:	learn: 0.6146240	total: 2m 31s	remaining: 516ms
# 9966:	learn: 0.6146240	total: 2m 31s	remaining: 501ms
# 9967:	learn: 0.6146240	total: 2m 31s	remaining: 486ms
# 9968:	learn: 0.6146240	total: 2m 31s	remaining: 470ms
# 9969:	learn: 0.6146240	total: 2m 31s	remaining: 455ms
# 9970:	learn: 0.6146240	total: 2m 31s	remaining: 440ms
# 9971:	learn: 0.6146240	total: 2m 31s	remaining: 425ms
# 9972:	learn: 0.6146240	total: 2m 31s	remaining: 410ms
# 9973:	learn: 0.6146240	total: 2m 31s	remaining: 395ms
# 9974:	learn: 0.6146240	total: 2m 31s	remaining: 379ms
# 9975:	learn: 0.6146240	total: 2m 31s	remaining: 364ms
# 9976:	learn: 0.6146239	total: 2m 31s	remaining: 349ms
# 9977:	learn: 0.6146239	total: 2m 31s	remaining: 334ms
# 9978:	learn: 0.6146239	total: 2m 31s	remaining: 319ms
# 9979:	learn: 0.6146239	total: 2m 31s	remaining: 303ms
# 9980:	learn: 0.6146239	total: 2m 31s	remaining: 288ms
# 9981:	learn: 0.6146237	total: 2m 31s	remaining: 273ms
# 9982:	learn: 0.6146237	total: 2m 31s	remaining: 258ms
# 9983:	learn: 0.6146237	total: 2m 31s	remaining: 243ms
# 9984:	learn: 0.6146237	total: 2m 31s	remaining: 228ms
# 9985:	learn: 0.6146237	total: 2m 31s	remaining: 213ms
# 9986:	learn: 0.6146237	total: 2m 31s	remaining: 197ms
# 9987:	learn: 0.6146237	total: 2m 31s	remaining: 182ms
# 9988:	learn: 0.6146237	total: 2m 31s	remaining: 167ms
# 9989:	learn: 0.6146237	total: 2m 31s	remaining: 152ms
# 9990:	learn: 0.6146237	total: 2m 31s	remaining: 137ms
# 9991:	learn: 0.6146235	total: 2m 31s	remaining: 121ms
# 9992:	learn: 0.6146235	total: 2m 31s	remaining: 106ms
# 9993:	learn: 0.6146235	total: 2m 31s	remaining: 91.1ms
# 9994:	learn: 0.6146235	total: 2m 31s	remaining: 75.9ms
# 9995:	learn: 0.6146234	total: 2m 31s	remaining: 60.7ms
# 9996:	learn: 0.6146234	total: 2m 31s	remaining: 45.6ms
# 9997:	learn: 0.6146234	total: 2m 31s	remaining: 30.4ms
# 9998:	learn: 0.6146234	total: 2m 31s	remaining: 15.2ms
# 9999:	learn: 0.6146234	total: 2m 31s	remaining: 0us
# TransformedTargetRegressor(regressor=Pipeline(steps=[('third_encoder',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('label',
#                                                                                        OrdinalEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         5,
#                                                                                         4])])),
#                                                      ('model',
#                                                       <catboost.core.CatBoostRegressor object at 0x000001BAB7FA2E50>)]),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
linear_pipe.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('first_encoder',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second_encoder',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('one_hot',
#                                                                                        OneHotEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         5,
#                                                                                         4])])),
#                                                      ('model',
#                                                       LinearRegression())]),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
extra_pipe.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('first_encoder',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second_encoder',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('one_hot',
#                                                                                        OneHotEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         5,
#                                                                                         4])])),
#                                                      ('model',
#                                                       ExtraTreesRegressor(bootstrap=True,
#                                                                           criterion='friedman_mse',
#                                                                           n_estimators=1000))]),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
ada_pipe.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('first_encoder',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second_encoder',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('one_hot',
#                                                                                        OneHotEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         5,
#                                                                                         4])])),
#                                                      ('model',
#                                                       AdaBoostRegressor(learning_rate=0.01,
#                                                                         loss='exponential',
#                                                                         n_estimators=1000))]),
#                            transformer=PowerTransformer(method='box-cox'))

# %% [markdown]
# <div align="center"><h3>4.1. Enter Data Modelling Code Here</h3></div>

# %% [markdown]
# ---

# %% [markdown]
# <div><h3>05. Model Evaluation</h3></div>

# %% [markdown]
# The trained model is in need of evaluation. The main metrics of interest are ___R2___ and ___RMSE___. This is due to the fact that the problem is a regression problem.

# %% [markdown]
# <div align="center"><h3>5.1. Enter Model Evaluation Code Here</h3></div>

# %% [markdown]
# #### 5.1. Preliminary Evaluation
#
# Here, we evaluate the preliminary models trained prior.

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
def root_mean_squared_error(y_true, y_pred):
    value = np.sqrt(mean_squared_error(y_true, y_pred))
    return value

# %%
def generate_model_score(model, data, metric_name, metric):
    X, y = data
    pred = model.predict(X)
    score = metric(y, pred)
    return score

# %%
def print_metrics(metric, train_score, test_score, factor=100, suffix="%"):
    print(f"Train {metric} = {factor * train_score: .3f}{suffix}")
    print(f"Test {metric} = {factor * test_score: .3f}{suffix}")
    print(f"Generalization error = {factor * (train_score - test_score): .3f}{suffix}")

    return

# %%
def test_model(model, data, metric_name, metric):
    train, test = data

    if isinstance(metric_name, str):
        train_score = generate_model_score(model, train, metric_name, metric)
        test_score = generate_model_score(model, test, metric_name, metric)

        factor = 1 if metric_name.lower() == "rmse" else 100
        suffix = "" if metric_name.lower() == "rmse" else "%"

        print_metrics(metric_name.lower().capitalize(), train_score, test_score, factor = factor, suffix = suffix)
    else:
        for (name, m) in zip(metric_name, metric):
            train_score = generate_model_score(model, train, name, m)
            test_score = generate_model_score(model, test, name, m)

            factor = 1 if name.lower() == "rmse" else 100
            suffix = "" if name.lower() == "rmse" else "%"

            print_metrics(name.lower().capitalize(), train_score, test_score, factor = factor, suffix = suffix)
            print("="*20 + "\n")

    return

# %%
# Metrics
metric_name = ["R2", "RMSE",]
metric = [r2_score, root_mean_squared_error,]

# %%
# Test Catboost pipeline
test_model(cat_pipe, [[X_train, y_train], [X_test, y_test]], metric_name, metric)
# Out:
# Train R2 =  31.441%
# Test R2 =  31.257%
# Generalization error =  0.184%
# ====================
#
# Train Rmse =  366.187
# Test Rmse =  388.268
# Generalization error = -22.081
# ====================

# %%
# Test linear regression pipeline
test_model(linear_pipe, [[X_train, y_train], [X_test, y_test]], metric_name, metric)
# Out:
# Train R2 =  7.205%
# Test R2 =  6.156%
# Generalization error =  1.049%
# ====================
#
# Train Rmse =  426.023
# Test Rmse =  453.649
# Generalization error = -27.625
# ====================

# %%
# Test ExtraTrees pipeline
test_model(extra_pipe, [[X_train, y_train], [X_test, y_test]], metric_name, metric)
# Out:
# Train R2 =  21.389%
# Test R2 =  21.873%
# Generalization error = -0.485%
# ====================
#
# Train Rmse =  392.115
# Test Rmse =  413.920
# Generalization error = -21.805
# ====================

# %%
# Test AdaBoost pipeline
test_model(ada_pipe, [[X_train, y_train], [X_test, y_test]], metric_name, metric)
# Out:
# Train R2 =  7.503%
# Test R2 =  6.844%
# Generalization error =  0.659%
# ====================
#
# Train Rmse =  425.338
# Test Rmse =  451.984
# Generalization error = -26.646
# ====================

# %% [markdown]
# #### 5.3 Performance Analysis
#
# Due to stochasticity, running the code multiple times will likely give slightly different results. However, on the whole, we can state the following:
#
# 1. All the models seem to have limited performance on this dataset.
#
# 2. With respect to R2 score magnitude:
#
#    1. Catboost
#
#    2. ExtraTrees
#
#    3. AdaBoost and
#
#    4. Linear regression
#
# 4. The Catboost model seems to have the smallest generalization gap based on R2 score. With respect to the RMSE score though, it seems to have a large gap.

# %% [markdown]
# It would seem that the Catboost model performs best. As such, further efforts will be focused on it.

# %% [markdown]
# ## Set up MLflow

# %%
# import needed libraries
import mlflow
import mlflow.sklearn
from mlflow.models import infer_signature
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
# Setup MLflow
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("jewelry_price_optimization")
# Out:
# <Experiment: artifact_location='file:///C:/Users/Promise Sunday/Documents/mlruns/353735458978682171', creation_time=1732838852655, experiment_id='353735458978682171', last_update_time=1732838852655, lifecycle_stage='active', name='jewelry_price_optimization', tags={}>

# %%
def root_mean_squared_error(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def log_model_to_mlflow(model_pipeline, model_name, X_train, X_test, y_train, y_test):
    """
    Log model, parameters, and metrics to MLflow
    """
    with mlflow.start_run(run_name=f"{model_name}_{datetime.now().strftime('%Y%m%d_%H%M%S')}") as run:
        # Get predictions
        train_predictions = model_pipeline.predict(X_train)
        test_predictions = model_pipeline.predict(X_test)
        
        # Calculate metrics
        metrics = {
            "train_r2": r2_score(y_train, train_predictions),
            "test_r2": r2_score(y_test, test_predictions),
            "train_rmse": root_mean_squared_error(y_train, train_predictions),
            "test_rmse": root_mean_squared_error(y_test, test_predictions)
        }
        
        # Log metrics
        mlflow.log_metrics(metrics)
        
        # Try to log model parameters
        try:
            model = model_pipeline.regressor_.named_steps['model']
            params = model.get_params()
            mlflow.log_params(params)
        except:
            print(f"Warning: Could not log parameters for {model_name}")
        
        # Log the model
        try:
            signature = infer_signature(X_train, train_predictions)
            mlflow.sklearn.log_model(
                sk_model=model_pipeline,
                artifact_path=f"{model_name}_model",
                signature=signature
            )
        except Exception as e:
            print(f"Warning: Logging model without signature for {model_name}")
            mlflow.sklearn.log_model(
                sk_model=model_pipeline,
                artifact_path=f"{model_name}_model"
            )
        
        print(f"\nLogged {model_name} model to MLflow")
        print(f"Run ID: {run.info.run_id}")
        print("\nMetrics:")
        for metric_name, value in metrics.items():
            print(f"{metric_name}: {value:.4f}")

# Log each model
models = {
    "catboost": cat_pipe,
    "linear_regression": linear_pipe,
    "extra_trees": extra_pipe,
    "adaboost": ada_pipe
}

# Log all models
for name, model in models.items():
    print(f"\nLogging {name} model...")
    try:
        log_model_to_mlflow(model, name, X_train, X_test, y_train, y_test)
    except Exception as e:
        print(f"Error logging {name} model: {str(e)}")
# Out:
# Logging catboost model...
# Warning: Logging model without signature for catboost
#
# Logged catboost model to MLflow
# Run ID: 4d9d81ff8d2f44a58a804a2331e84063
#
# Metrics:
# train_r2: 0.3144
# test_r2: 0.3126
# train_rmse: 366.1871
# test_rmse: 388.2679
#
# Logging linear_regression model...
# Warning: Logging model without signature for linear_regression
#
# Logged linear_regression model to MLflow
# Run ID: b17acae755d34022a4b1623899b6a03e
#
# Metrics:
# train_r2: 0.0720
# test_r2: 0.0616
# train_rmse: 426.0234
# test_rmse: 453.6489
#
# Logging extra_trees model...
# Warning: Logging model without signature for extra_trees
#
# Logged extra_trees model to MLflow
# Run ID: 1f9e3e316d7a4ebdac4c4a47b96d7272
#
# Metrics:
# train_r2: 0.2139
# test_r2: 0.2187
# train_rmse: 392.1149
# test_rmse: 413.9203
#
# Logging adaboost model...
# Warning: Logging model without signature for adaboost
#
# Logged adaboost model to MLflow
# Run ID: ec3b6d3c40d942e4b824b946f86e573e
#
# Metrics:
# train_r2: 0.0750
# test_r2: 0.0684
# train_rmse: 425.3378
# test_rmse: 451.9839

# %%
# Set the experiment and get its ID
experiment = mlflow.set_experiment("jewelry_price_optimization")

# Create a new run with a unique ID
with mlflow.start_run(experiment_id=experiment.experiment_id):
    mlflow.log_param("test_param", 1)
    mlflow.log_metric("test_metric", 100)
    print("Run ID:", mlflow.active_run().info.run_id)
    
print("Test run completed - check MLflow UI!")
# Out:
# Run ID: edcfec4e0d444770b36f32e72ae44be6
# Test run completed - check MLflow UI!

# %%
print(f"MLflow version: {mlflow.__version__}")
# Out:
# MLflow version: 2.8.1

# %%
# Now fetch all runs for visualization
runs = mlflow.search_runs(experiment.experiment_id)

def create_model_comparison_plots(runs_df):
    """
    Create a set of visualizations comparing model performance
    """
    # Set the style for better-looking plots
    plt.style.use('default')  # Changed from 'seaborn' to 'default'
    
    # Set a clean, modern look
    plt.rcParams['figure.facecolor'] = 'white'
    plt.rcParams['axes.grid'] = True
    plt.rcParams['grid.alpha'] = 0.3
    
    # Create a figure with multiple subplots
    fig = plt.figure(figsize=(20, 12))
    
    # 1. R2 Score Comparison
    plt.subplot(2, 2, 1)
    comparison_data = pd.melt(runs_df, 
                             id_vars=['tags.mlflow.runName'],
                             value_vars=['metrics.train_r2', 'metrics.test_r2'],
                             var_name='dataset',
                             value_name='R2 Score')
    
    # Clean up labels
    comparison_data['dataset'] = comparison_data['dataset'].map({
        'metrics.train_r2': 'Training',
        'metrics.test_r2': 'Testing'
    })
    comparison_data['Model'] = comparison_data['tags.mlflow.runName'].apply(
        lambda x: x.split('_')[0] if pd.notnull(x) else 'Unknown'
    )
    
    sns.barplot(data=comparison_data, x='Model', y='R2 Score', hue='dataset', palette='Blues')
    plt.title('R² Score Comparison Across Models', pad=20)
    plt.xticks(rotation=45)
    
    # 2. RMSE Comparison
    plt.subplot(2, 2, 2)
    rmse_data = pd.melt(runs_df,
                        id_vars=['tags.mlflow.runName'],
                        value_vars=['metrics.train_rmse', 'metrics.test_rmse'],
                        var_name='dataset',
                        value_name='RMSE')
    
    rmse_data['dataset'] = rmse_data['dataset'].map({
        'metrics.train_rmse': 'Training',
        'metrics.test_rmse': 'Testing'
    })
    rmse_data['Model'] = rmse_data['tags.mlflow.runName'].apply(
        lambda x: x.split('_')[0] if pd.notnull(x) else 'Unknown'
    )
    
    sns.barplot(data=rmse_data, x='Model', y='RMSE', hue='dataset', palette='Blues')
    plt.title('RMSE Comparison Across Models', pad=20)
    plt.xticks(rotation=45)
    
    # 3. Generalization Gap
    plt.subplot(2, 2, 3)
    runs_df['R2_gap'] = runs_df['metrics.train_r2'] - runs_df['metrics.test_r2']
    runs_df['RMSE_gap'] = runs_df['metrics.train_rmse'] - runs_df['metrics.test_rmse']
    
    gap_data = pd.melt(runs_df,
                       id_vars=['tags.mlflow.runName'],
                       value_vars=['R2_gap', 'RMSE_gap'],
                       var_name='metric',
                       value_name='gap')
    
    gap_data['Model'] = gap_data['tags.mlflow.runName'].apply(
        lambda x: x.split('_')[0] if pd.notnull(x) else 'Unknown'
    )
    
    sns.barplot(data=gap_data, x='Model', y='gap', hue='metric', palette='Blues')
    plt.title('Generalization Gap by Model', pad=20)
    plt.xticks(rotation=45)
    
    # 4. Performance Scatter Plot
    plt.subplot(2, 2, 4)
    sns.scatterplot(data=runs_df, 
                    x='metrics.test_rmse', 
                    y='metrics.test_r2',
                    s=100,
                    color='blue')
    
    # Add model names as annotations
    for idx, row in runs_df.iterrows():
        plt.annotate(row['tags.mlflow.runName'].split('_')[0], 
                    (row['metrics.test_rmse'], row['metrics.test_r2']),
                    xytext=(5, 5), textcoords='offset points')
    
    plt.title('Test RMSE vs R² Score', pad=20)
    plt.xlabel('Test RMSE')
    plt.ylabel('Test R² Score')
    
    # Adjust layout and display
    plt.tight_layout()
    plt.show()
    
    # Print summary statistics
    print("\nSummary Statistics:")
    summary = runs_df.groupby(runs_df['tags.mlflow.runName'].apply(
        lambda x: x.split('_')[0] if pd.notnull(x) else 'Unknown'
    ))[['metrics.test_r2', 'metrics.test_rmse']].mean()
    
    print("\nTest Set Performance:")
    print(summary.round(4))

def plot_metric_history(experiment_id, metric_name):
    """
    Create a timeline plot for a specific metric across all runs
    """
    runs = mlflow.search_runs(experiment_id)
    
    # Convert start_time to datetime
    runs['start_time'] = pd.to_datetime(runs['start_time'])
    
    # Sort by start_time
    runs = runs.sort_values('start_time')
    
    plt.figure(figsize=(12, 6))
    
    colors = plt.cm.Blues(np.linspace(0.5, 0.9, len(runs['tags.mlflow.runName'].unique())))
    
    for model, color in zip(runs['tags.mlflow.runName'].unique(), colors):
        model_runs = runs[runs['tags.mlflow.runName'] == model]
        plt.plot(model_runs['start_time'], 
                model_runs[f'metrics.{metric_name}'],
                'o-',
                label=model.split('_')[0],
                color=color)
    
    plt.title(f'{metric_name} Over Time', pad=20)
    plt.xlabel('Run Time')
    plt.ylabel(metric_name)
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# Create all visualizations
create_model_comparison_plots(runs)
plot_metric_history(experiment.experiment_id, 'test_r2')
plot_metric_history(experiment.experiment_id, 'test_rmse')
# Out:
# Run ID: 472fa6c5313b4156a8e3a9e7c19553da
# Test run completed - check MLflow UI!
# Summary Statistics:
#
# Test Set Performance:
#                      metrics.test_r2  metrics.test_rmse
# tags.mlflow.runName
# adaboost                      0.0684           451.9839
# catboost                      0.3126           388.2679
# enthused-bear-970                NaN                NaN
# extra                         0.2187           413.9203
# gentle-flea-127                  NaN                NaN
# linear                        0.0616           453.6489
# skillful-ray-973                 NaN                NaN

# %% [markdown]
# As can be seen from the short model optimization carried out above, the model performancce may be considered to have shown very slight improvement in terms of:
# - Metric magnitude, and
# - Generalization error.
#
# The consequence of this is that the optimized Random Forest model is of better performance than the original out-of-box Random Forest model.

# %% [markdown]
# ---

# %% [markdown]
# <div><h3>06. Model Deployment</h3></div>

# %% [markdown]
# With the model performace up to speed, the final artefact needs to be deployed for use. There are a number of options. They include:
#
#
# 1. Local Deployment
#    * Flask
#    * Django
# 2. Cloud Deployment
#    * AWS
#    * GCP
#    * Streamlit + GitHub
